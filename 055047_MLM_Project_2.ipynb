# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha-Gupta-10/MLM-Project-2/blob/main/055047_MLM_Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DATA REPORT

# %% [markdown]
# Project Information
#
# Project Title: Build Supervised Learning Models using Python: Classification & Regression {Logistic Regression | Decision Trees}
#
# Student Name and Enrollment Number: Sneha Gupta (055047)

# %% [markdown]
# Description of Data
#
# **Data Source:** https://www.kaggle.com/datasets/chakilamvishwas/imports-exports-15000
#
# **Data Size:**  Approximately 15000 observations and 16 variables
#
# **Data Type:** Cross-Sectional
#
# **Data Dimension:** Number of Variable - 16; Number of Observations - 15,000
#
# **Data Variable Type**:
#
# **Numeric:**
#
#
# *   **Integer:** Quantity, Customs_Code
# *   **Decimal:** Value, Weight
#
# **Non-Numeric:**
# - Country
# - Product
# - Import_Export
# - Category
# - Port
# - Shipping_Method
# - Supplier
# - Customer
# - Payment_Terms
# - Date
# - Transaction_ID
#
# **Data Variable Category-I:**
#
# **Index:** Transaction_ID
#
# **Categorical:** Country, Product, Import_Export, Category, Port, Shipping_Method, Supplier, Customer, Payment_Terms
#
# **Non-Categorical:** Quantity, Value, Date, Weight, Customs_Code
#
# **Data Variable Category-II:**
#
# **Input Variables or Features**: All variables for classification
#
# **Outcome Variable(s) or Feature(s)**:
#
# **About Dataset:**
# The dataset contains several categorical variables that provide descriptive information about the transactions. These include Country, which indicates the nation involved in the trade; Product, specifying the type of goods being imported or exported; and Import_Export, identifying the transaction as either an import or export activity. Other categorical fields such as Category classify the products into broader groups like electronics or clothing, while Port and Shipping_Method describe the logistics of the transaction, including the port of entry/exit and the mode of transport. Additionally, variables like Supplier and Customer highlight the parties involved in the trade, and Payment_Terms outlines the agreed financial conditions. Finally, Date records the transaction's occurrence time, and Transaction_ID uniquely identifies each record in the dataset. These variables will require preprocessing, such as encoding, to be suitable for clustering algorithms.

# %% [markdown]
# Project Objectives | Problem Statements
#
# 1. Accurate Classification of Transactions:
# - To accurately classify transactions into different categories to improve business decision-making.
#
# 2. Identification of Key Drivers for Classification:
# - To find most significant factors that influence the classification of transactions, and how do these factors interact.
#
# 3. Improved Business Decision Making:
# - To leverage the classification models to make more informed decisions.
#
# 4. Optimized Resource Allocation:
# - To optimize the allocation of resources based on the insights gained from the classification models.
#
# 5. Deeper Understanding of Data Patterns:
# - To use the classification models to gain a deeper understanding of the underlying patterns and relationships within the data to improve business operations and gain a competitive advantage.

# %% [markdown]
# ANALYTICAL REPORT

# %% [markdown]
# Analysis of Data
#
# Data Preprocessing
#
# Treatment of Missing Data
#
# There are no missing values in the dataset.
# But if it arises later, then:
#
# Variables with more than 50% missing values will be removed. This is a common approach to handle variables with high levels of missing data, as they might not provide sufficient information for analysis.
#
# For variables with less than 50% missing values, imputation techniques will be used. The specific imputation method (mean, median, or mode) was not explicitly stated, but it was likely chosen based on the data type and distribution of each variable.
#
# Numerical Encoding of Non-Numeric Categorical Data
#
# **Import_Export** : Export = 0, Import = 1
#
# **Category** : Clothing = 0, Electronics = 1, Furniture = 2, Machine = 3, Toys = 4
#
# **Shipping_Method** : Air = 0, Land = 1, Sea =2
#
# **Payment_Terms** : Cash on Delivery = 0, Net 30 = 1, Net 60 = 2, Prepaid = 3
#
# Re-Scaling & Transformation of Numeric Data (Treatment of Data having Outliers)
#
# - Outliers: Outliers can significantly impact the performance of distance-based models like K-Nearest Neighbors. Scaling techniques like standardization or normalization can help to reduce the influence of outliers.
# - Feature Scaling: Different features can have vastly different scales. Scaling techniques bring the features to a common scale, which can improve the performance of many machine learning algorithms, including distance-based models and gradient-based models like XGBoost.
# - Skewed Distributions: Log transformation can be used to address skewed distributions in numerical data, making the data more suitable for certain machine learning algorithms.
#
# Weight_mmnorm appears to have a more uniform distribution compared to the other two rescaled variables.

# %% [markdown]
# Descriptive Statistics
#
# Categorical Variables
#
# - Country:
#
# High cardinality: The number of unique countries is relatively high (243).
#
# Most frequent countries: Congo (48 occurrences), Korea (36 occurrences), Bahamas (34 occurrences).
#
# - Product:
#
# Extremely high cardinality (967 unique products).
#
# Some products have very low frequencies (e.g., "inside", "today", "fast").
#
# - Import_Export:
#
# Relatively balanced distribution between "Import" (50.87%) and "Export" (49.13%).
#
# - Date:
# High cardinality (1708 unique dates).
# Many dates have low frequencies.
#
# - Category:
# Relatively balanced distribution across the five categories.
#
# - Port:
# Extremely high cardinality (4257 unique ports).
# Many ports have very low frequencies.
#
# - Shipping_Method:
# Relatively balanced distribution across "Land", "Sea", and "Air".
#
# - Supplier:
# Extremely high cardinality (4566 unique suppliers).
# Many suppliers have very low frequencies.
#
# - Customer:
# Extremely high cardinality (4835 unique customers).
# Many customers have very low frequencies.
#
# - Payment_Terms:
# Relatively balanced distribution across the four payment terms.
#
# Non-Categorical Variable
#
# - Quantity, Value, Weight, Invoice_Number:
#
# Central Tendency:
#
# Mean, Median, and 25th/75th percentiles are relatively close for all variables, suggesting a roughly symmetric distribution (though this is further confirmed by the skewness values).
#
# Mode: The mode might not be a very informative measure of central tendency for these continuous variables as they likely have many unique values.
#
# Dispersion:
# High standard deviation values indicate significant variability within each variable.
#
# Range confirms the wide spread of values for each variable.
#
# Skewness values are close to zero for all variables, confirming the near-symmetric distribution.
#
# Kurtosis values are close to -1.2, suggesting a distribution slightly flatter than a normal distribution (which has a kurtosis of 0).
#
# Coefficient of Variation:
# Provides a relative measure of dispersion, showing that Quantity and Weight have slightly higher variability compared to Value and Customs_Code.
#
# Correlation:
# Low Pearson and Spearman correlations between all pairs of variables indicate weak linear relationships.

# %% [markdown]
# Data Visualization
#
# - Bar Chart 1:
#
# The bar plot visualizes the frequency distribution of the Import_Export variable.
#
# Categories: There are two categories: "Import" and "Export".
#
# "Import" has approximately 2500 occurrences.
# "Export" has approximately 2450 occurrences.
#
# Distribution: The distribution between "Import" and "Export" appears to be relatively balanced.
#
# - Bar Chart 2:
#
# The bar plot visualizes the frequency distribution of the Category variable.
#
# Categories: There are five categories: "Clothing", "Machinery", "Electronics", "Furniture", and "Toys".
#
# "Clothing" has the highest count, followed by "Electronics" and "Machinery".
# "Toys" and "Furniture" have slightly lower counts.
#
# Insights:
#
# Most Frequent Categories: "Clothing", "Electronics", and "Machinery" are the most frequently occurring categories in the dataset.
# The distribution across the categories is relatively balanced, with no single category dominating significantly.
#
# - Bar Chart 3:
#
# This plot visually represents the counts of "Import" and "Export" transactions for each of the five product categories: Clothing, Electronics, Furniture, Machinery, and Toys.
#
# Key Insights:
#
# Category-wise Trade Volume:
#
# Clothing and Electronics: These categories have the highest overall trade volume, with both imports and exports being substantial.
#
# Machinery and Toys: These categories also show a good balance between imports and exports, but with slightly lower overall volumes compared to Clothing and Electronics.
#
# Furniture: This category seems to have a slightly higher volume of imports compared to exports.
#
# Import-Export Balance:
#
# Overall, the plot suggests a relatively balanced trade across all categories, with no single category showing a significant dominance of imports or exports.
#
# Potential Use Cases:
#
# Trade Analysis: This plot provides a quick overview of the trade patterns for different product categories, highlighting the categories with the highest trade volume and potential imbalances.
#
# Market Research: It can help businesses identify potential markets for their products based on the trade volume and trends in different categories.
#
# Inventory Management: Retailers and wholesalers can use this information to optimize inventory levels for different product categories.
#
# - Pie Chart 1:
#
# The pie chart visualizes the distribution of shipping methods used in the dataset.
#
# Shipping Methods: There are three shipping methods: Land, Sea, and Air.
#
# Distribution:
# Land: Approximately 33.5% of shipments are transported by land.
# Sea: Approximately 33.3% of shipments are transported by sea.
# Air: Approximately 33.2% of shipments are transported by air.
#
# Insights:
#
# Balanced Distribution: The distribution of shipping methods is relatively balanced, with each method accounting for approximately one-third of the total shipments.
#
# No Dominant Method: There isn't a single dominant shipping method used in the dataset.
#
# - Pie Chart 2:
#
# The pie chart visualizes the distribution of payment terms used in the transactions.
#
# Terms: There are four payment terms: Cash on Delivery, Net 60, Prepaid, and Net 30.
#
# Distribution:
#
# Cash on Delivery: Approximately 25.6% of transactions are paid using this method.
#
# Net 60: Approximately 25.0% of transactions have a payment term of 60 days.
#
# Prepaid: Approximately 24.9% of transactions are prepaid.
#
# Net 30: Approximately 24.5% of transactions have a payment term of 30 days.
#
# Insights:
#
# Balanced Distribution: The distribution of payment terms is relatively balanced, with no single term dominating significantly.
#
# Cash on Delivery and Net 60: These two terms are slightly more prevalent than Prepaid and Net 30.
#
# - Scatter Plot 1:
#
# The plot visualizes the relationship between two variables:
#
# Shipping Method: Categorical variable, likely represented by numerical codes (0, 1, 2).
#
# Import_Export: Categorical variable, likely represented by numerical codes (0 for Import, 1 for Export).
#
# Quantity_mmnorm: The size of the markers represents the Quantity_mmnorm, indicating the normalized quantity of goods. Larger markers correspond to higher quantities.
#
# Payment_Terms_code: The color of the markers represents the Payment_Terms_code, likely indicating different payment terms.
#
# Insights:
#
# Relationship between Shipping Method and Import/Export: The plot doesn't show a clear linear relationship between Shipping Method and Import/Export. The markers are scattered across the plot, suggesting that the choice of shipping method may not be strongly associated with whether a transaction is an import or export.
#
# Quantity Variation: The size of the markers indicates that the quantity of goods shipped varies across different combinations of Shipping Method and Import/Export. Some combinations have higher quantities compared to others.
#
# Payment Terms Influence: The color coding suggests that the payment terms might also influence the quantity shipped or the choice of shipping method. However, the exact nature of this influence is not immediately clear from the plot.
#
# - Scatter Plot 2:
#
# The plot visualizes the relationship between two variables:
#
# Shipping_Method: Categorical variable with three levels: Sea, Air, and Land.
#
# Quantity: Continuous variable representing the quantity of goods shipped.
#
# Data Representation:
#
# The plot uses a color gradient to represent the quantity of goods shipped. Darker colors correspond to higher quantities.
# Each shipping method is represented by a vertical line of points.
# The density of points along each line indicates the frequency of transactions with different quantities for that shipping method.
#
# Insights:
#
# Distribution of Quantities: All three shipping methods (Sea, Air, Land) show a wide range of quantities shipped, with some transactions involving very large quantities. There seems to be a concentration of transactions with lower quantities for all shipping methods.
#
# Shipping Method and Quantity: At first glance, there isn't a clear, distinct pattern suggesting a strong relationship between the shipping method and the quantity of goods shipped. All three methods show a similar range of quantities.
#
# - Line Chart:
#
# The plot visualizes the total quantity and value for each of the five product categories (represented by the x-axis).
#
# Trends:
#
# Quantity: The total quantity appears to decrease from Category 0 to Category 4, with a slight increase between Category 2 and 3.
#
# Value: The total value also shows a decreasing trend, with a steeper decline from Category 0 to 1, followed by a more gradual decrease.
#
# Insights:
#
# Category-wise Differences: The plot reveals significant differences in the total quantity and value across the five categories. Category 0 appears to have the highest total quantity and value, while Category 4 has the lowest.
#
# Relationship between Quantity and Value: While both quantity and value generally decrease across the categories, the relationship between them is not perfectly linear.
#
# - Box Plot:
#
# The box plot represents the distribution of a variable within a single category.
#
# Outliers: There are no visible outliers in this box plot.
#
# Central Tendency: The median value of the variable within this category is around 2.
#
# Spread: The data points are relatively spread out, as indicated by the moderate width of the box.
#
# Symmetry: The median line is closer to the top of the box, suggesting that the distribution might be slightly skewed to the right.
#
# - Pair Plot:
#
# The pairplot visualizes the relationships between three categorical variables:
# Category_code, Shipping_Method_code, Payment_Terms_code
#
# Category_code vs. Shipping_Method_code: The scatter plot shows no clear pattern or relationship between these two variables. The points seem to be randomly distributed.
#
# Category_code vs. Payment_Terms_code: There appears to be some structure in this plot. The points are not completely random and show a slight clustering pattern. This suggests a weak or moderate relationship between these two variables.
#
# Shipping_Method_code vs. Payment_Terms_code: Similar to the first plot, there is no clear pattern or relationship visible between these two variables. The points seem to be randomly distributed.
#
# Density Plots: The density plots show the distribution of each variable. Category_code and Payment_Terms_code have multiple peaks, suggesting that certain categories and payment terms are more frequent than others. Shipping_Method_code appears to have a more uniform distribution.
#
# - Correlation Heatmap:
#
# Quantity vs. Value: There is a weak negative correlation between Quantity and Value (-0.01). This suggests that, in general, as the quantity of goods increases, the value per unit tends to slightly decrease. However, the relationship is very weak.
#
# Quantity vs. Weight: A weak positive correlation (0.02) exists between Quantity and Weight. This indicates that, on average, as the quantity of goods increases, the weight also tends to increase slightly. The relationship is again very weak.
#
# Value vs. Weight: A strong positive correlation (0.8) is observed between Value and Weight. This suggests that, in general, as the weight of the goods increases, their value also tends to increase significantly.

# %% [markdown]
# Inferential Statistics
#
# Categorical Variable:
#
# Shipping_Method and Import_Export
#
# - Chi-Square Test:
#
# The Chi-Square statistic is 0.7294.
# The p-value is 0.6944, which is greater than the typical significance level of 0.05.
# This indicates that there is no significant difference in the distribution of shipping methods between imports and exports. In other words, shipping methods are used in similar proportions for both imports and exports.
#
# Expected Frequencies: The provided table shows the expected frequencies under the null hypothesis (i.e., no association between shipping method and import/export). The observed frequencies are likely close to the expected frequencies, supporting the conclusion of no significant association.
#
# Non-Categorical Variables:
#
# Quantity, Value, Weight
#
# - Tests of Normality:
#
# All three variables (Quantity, Value, Weight) show strong evidence of non-normality based on all four tests (Shapiro-Wilk, Kolmogorov-Smirnov, Anderson-Darling, Jarque-Bera).
#
# The p-values for all tests are very small, indicating that the distributions of these variables are significantly different from a normal distribution.
#
# - Test of Correlation:
#
# Quantity and Value: A weak negative correlation is observed (-0.007698). The t-statistic is not significant (p-value = 0.586), indicating that the observed correlation is likely due to chance.
#
# Quantity and Weight: A very weak positive correlation is observed (0.017973). The t-statistic is also not significant (p-value = 0.203), suggesting no significant linear relationship between these variables.
#
# Value and Weight: A weak positive correlation is observed (0.008844). The t-statistic is not significant (p-value = 0.531), indicating no significant linear relationship between these variables.

# %% [markdown]
# Supervised Machine Learning Models
#
# - Logistic Regression
#
# Accuracy: 1.00 - This indicates that the model correctly predicted the class for all instances in the dataset.
#
# Classification Report:
#
# Precision: 1.00 for both classes - This means that all instances predicted as class 0 were actually class 0, and all instances predicted as class 1 were actually class 1.
#
# Recall: 1.00 for both classes - This means that the model correctly identified all instances of class 0 and class 1.
#
# F1-score: 1.00 for both classes - This metric balances precision and recall, and a score of 1.00 indicates perfect performance.
#
# Support: The number of instances for each class in the dataset.
#
# Confusion Matrix:
#
# True Positives (TP): 501 - The number of instances correctly predicted as class 0.
#
# True Negatives (TN): 500 - The number of instances correctly predicted as class 1.
#
# False Positives (FP): 0 - The number of instances incorrectly predicted as class 0 when they were actually class 1.
#
# False Negatives (FN): 0 - The number of instances incorrectly predicted as class 1 when they were actually class 0.
#
# Interpretation:
#
# The results indicate that the Logistic Regression model has performed exceptionally well on this dataset. It achieved perfect accuracy, precision, recall, and F1-score for both classes. This suggests that the model has effectively learned the underlying patterns in the data and can accurately predict the class labels for new, unseen data.
#
# - Support Vector Machines
#
# Confusion Matrix
#
# True Positives (TP): 326 - Instances correctly predicted as class 0.
#
# True Negatives (TN): 397 - Instances correctly predicted as class 1.
#
# False Positives (FP): 398 - Instances incorrectly predicted as class 0 when they were actually class 1.
#
# False Negatives (FN): 380 - Instances incorrectly predicted as class 1 when they were actually class 0.
#
# Classification Report
#
# Precision (Class 0): 0.46 - Of all the instances predicted as class 0, 46% were actually class 0.
#
# Recall (Class 0): 0.45 - Of all the actual instances of class 0, 45% were correctly predicted.
#
# F1-score (Class 0): 0.46 - The harmonic mean of precision and recall for class 0.
#
# Precision (Class 1): 0.50 - Of all the instances predicted as class 1, 50% were actually class 1.
#
# Recall (Class 1): 0.51 - Of all the actual instances of class 1, 51% were correctly predicted.
#
# F1-score (Class 1): 0.51 - The harmonic mean of precision and recall for class 1.
#
# Accuracy: 0.48 - The overall accuracy of the model, indicating that it correctly predicted the class for 48% of the instances.
#
# Macro Average: The average of the metrics (precision, recall, F1-score) calculated for each class.
#
# Weighted Average: The weighted average of the metrics, considering the class support (number of instances in each class).
#
# Interpretation:
#
# The SVM model's performance is moderate. The accuracy, precision, recall, and F1-score are all around 0.48, indicating that the model is not making accurate predictions for both classes.
#
# - Stochastic Gradient Descent
#
# Confusion Matrix
#
# True Positives (TP): 724 - Instances correctly predicted as class 0.
#
# True Negatives (TN): 0 - Instances correctly predicted as class 1.
#
# False Positives (FP): 0 - Instances incorrectly predicted as class 0 when they were actually class 1.
#
# False Negatives (FN): 777 - Instances incorrectly predicted as class 1 when they were actually class 0.
#
# Classification Report:
#
# Precision (Class 0): 0.48 - Of all the instances predicted as class 0, 48% were actually class 0.
#
# Recall (Class 0): 1.00 - All instances of class 0 were correctly predicted.
# F1-score (Class 0): 0.65 - The harmonic mean of precision and recall for class 0.
#
# Precision (Class 1): 0.00 - None of the instances predicted as class 1 were actually class 1.
#
# Recall (Class 1): 0.00 - None of the instances of class 1 were correctly predicted.
#
# F1-score (Class 1): 0.00 - The harmonic mean of precision and recall for class 1.
#
# Accuracy: 0.48 - The overall accuracy of the model, indicating that it correctly predicted the class for 48% of the instances.
#
# Macro Average: The average of the metrics (precision, recall, F1-score) calculated for each class.
#
# Weighted Average: The weighted average of the metrics, considering the class support (number of instances in each class).
#
# Interpretation:
#
# The SGD model's performance is poor. While it achieves 100% recall for class 0 (meaning it correctly identifies all instances of class 0), it completely fails to predict any instances of class 1. This results in low precision, recall, and F1-score for class 1, and consequently, low overall accuracy.
#
# - Decision Tree
#
# Accuracy: 1.00 - The model achieved perfect accuracy, correctly predicting the class for all instances.
#
# Precision, Recall, F1-score: 1.00 for all classes - These metrics indicate that the model perfectly predicted all instances of each class.
#
# Confusion Matrix: The confusion matrix confirms the perfect performance, with all instances correctly classified into their respective classes.
#
# Interpretation:
#
# The Decision Tree model exhibits excellent performance on this dataset. It perfectly predicts all classes, achieving 100% accuracy. This suggests that the model has effectively learned the underlying patterns in the data and can accurately classify new, unseen data.
#
# - K-Nearest Neighbors
#
# Confusion Matrix
#
# True Positives (TP): 359 - Instances correctly predicted as class 0.
#
# True Negatives (TN): 381 - Instances correctly predicted as class 1.
#
# False Positives (FP): 365 - Instances incorrectly predicted as class 0 when they were actually class 1.
#
# False Negatives (FN): 396 - Instances incorrectly predicted as class 1 when they were actually class 0.
#
# Classification Report
#
# Precision (Class 0): 0.48 - Of all the instances predicted as class 0, 48% were actually class 0.
#
# Recall (Class 0): 0.50 - Of all the actual instances of class 0, 50% were correctly predicted.
#
# F1-score (Class 0): 0.49 - The harmonic mean of precision and recall for class 0.
#
# Precision (Class 1): 0.51 - Of all the instances predicted as class 1, 51% were actually class 1.
#
# Recall (Class 1): 0.49 - Of all the actual instances of class 1, 49% were correctly predicted.
#
# F1-score (Class 1): 0.50 - The harmonic mean of precision and recall for class 1.
#
# Accuracy: 0.49 - The overall accuracy of the model, indicating that it correctly predicted the class for 49% of the instances.
#
# Macro Average: The average of the metrics (precision, recall, F1-score) calculated for each class.
#
# Weighted Average: The weighted average of the metrics, considering the class support (number of instances in each class).
#
# Interpretation:
#
# The KNN model shows moderate performance. The accuracy, precision, recall, and F1-score are all around 0.49, indicating that the model is making reasonable predictions for both classes, but with room for improvement.
#
# - Naive Bayes model
#
# Confusion Matrix
#
# True Positives (TP): 298 - Instances correctly predicted as class 0.
#
# True Negatives (TN): 425 - Instances correctly predicted as class 1.
#
# False Positives (FP): 426 - Instances incorrectly predicted as class 0 when they were actually class 1.
#
# False Negatives (FN): 376 - Instances incorrectly predicted as class 1 when they were actually class 0.
#
# Classification Report
#
# Precision (Class 0): 0.41 - Of all the instances predicted as class 0, 41% were actually class 0.
#
# Recall (Class 0): 0.41 - Of all the actual instances of class 0, 41% were correctly predicted.
#
# F1-score (Class 0): 0.41 - The harmonic mean of precision and recall for class 0.
#
# Precision (Class 1): 0.50 - Of all the instances predicted as class 1, 50% were actually class 1.
#
# Recall (Class 1): 0.53 - Of all the actual instances of class 1, 53% were correctly predicted.
#
# F1-score (Class 1): 0.51 - The harmonic mean of precision and recall for class 1.
#
# Accuracy: 0.47 - The overall accuracy of the model, indicating that it correctly predicted the class for 47% of the instances.
#
# Macro Average: The average of the metrics (precision, recall, F1-score) calculated for each class.
#
# Weighted Average: The weighted average of the metrics, considering the class support (number of instances in each class).
#
# Interpretation:
#
# The Naive Bayes model has moderate performance. The accuracy, precision, recall, and F1-score are around 0.47, indicating that the model is making reasonable predictions for both classes, but with room for improvement.
#
# Comparison with KNN:
#
# The Naive Bayes model has slightly lower accuracy (0.47 vs. 0.49) compared to the KNN model.
# The Naive Bayes model shows better performance for class 1 in terms of recall, while the KNN model has slightly higher precision for class 0.
#
# - Random Forest model
#
# Feature Importances
#
# Category_code: This feature has the highest importance, suggesting that it is the most influential factor in determining the target variable.
#
# Quantity_mmnorm: This feature also has a significant importance, indicating that the normalized quantity plays a role in the model's predictions.
#
# Other Features: The remaining features (Weight_mmnorm, Value_mmnorm, Payment_Terms_code, Shipping_Method_code, Import_Export_code) have relatively low importance scores, suggesting that they have less impact on the model's predictions.
#
# Model Performance
#
# Accuracy: 1.00 - The model achieved perfect accuracy, correctly predicting the class for all instances.
#
# Precision, Recall, F1-score: 1.00 for all classes - These metrics indicate that the model perfectly predicted all instances of each class.
#
# Confusion Matrix: The confusion matrix confirms the perfect performance, with all instances correctly classified into their respective classes.
#
# Interpretation:
#
# The Random Forest model exhibits excellent performance on this dataset, achieving perfect accuracy and precision, recall, and F1-scores for all classes. This indicates that the model has effectively learned the underlying patterns in the data and can accurately predict the target variable.
#
# - Extreme Gradient Boosting
#
# Confusion Matrix
#
# True Positives (TP): 349 - Instances correctly predicted as class 0.
#
# True Negatives (TN): 380 - Instances correctly predicted as class 1.
#
# False Positives (FP): 375 - Instances incorrectly predicted as class 0 when they were actually class 1.
#
# False Negatives (FN): 396 - Instances incorrectly predicted as class 1 when they were actually class 0.
#
# Classification Report
#
# Precision (Class 0): 0.48 - Of all the instances predicted as class 0, 48% were actually class 0.
#
# Recall (Class 0): 0.48 - Of all the actual instances of class 0, 48% were correctly predicted.
#
# F1-score (Class 0): 0.48 - The harmonic mean of precision and recall for class 0.
#
# Precision (Class 1): 0.51 - Of all the instances predicted as class 1, 51% were actually class 1.
#
# Recall (Class 1): 0.51 - Of all the actual instances of class 1, 51% were correctly predicted.
#
# F1-score (Class 1): 0.51 - The harmonic mean of precision and recall for class 1.
#
# Accuracy: 0.4963 - The overall accuracy of the model, indicating that it correctly predicted the class for 49.63% of the instances.
#
# Macro Average: The average of the metrics (precision, recall, F1-score) calculated for each class.
#
# Weighted Average: The weighted average of the metrics, considering the class support (number of instances in each class).
#
# Interpretation:
#
# The XGBoost model shows moderate performance. The accuracy, precision, recall, and F1-score are all around 0.50, indicating that the model is making reasonable predictions for both classes, but with room for improvement.
#
# Comparison with Other Models:
#
# Compared to other models analyzed earlier, XGBoost appears to have performance similar to KNN and slightly better than Naive Bayes.
#
# ---
#
# Cross-Validation (K-Fold)
#
# Fold Accuracies: All folds achieved perfect accuracy (1.0). This suggests that the model generalizes well to unseen data and is not overfitting to the training data.
#
# Average Accuracy: The average accuracy across all folds is 1.00, further confirming the model's strong performance.

# %% [markdown]
# Comparisons
#
# - Base Models: LR & DT
#
# Performance: Both models achieved perfect accuracy, making it difficult to choose based solely on performance.
#
# Interpretability: Decision Trees are generally considered more interpretable than Logistic Regression, as their decision-making process can be easily visualized and understood.
#
# Computational Cost: Decision Trees typically have lower computational costs than Logistic Regression, especially for large datasets.
#
# - Regression-based Model Comparisons: LR vs SVM
#
# Logistic Regression outperformed SVM in terms of accuracy in this case. Logistic Regression might be preferred due to its higher accuracy and potentially better interpretability.
#
# - Non-Parametric Model Comparisons: DT vs KNN
#
# Decision Tree outperformed KNN in terms of accuracy. Decision Trees are also generally more interpretable than KNN.
#
# - Cross Comparison of Models: LR vs DT
#
# Both models achieved perfect accuracy. The choice between them might depend on factors like interpretability and computational cost. Decision Trees are generally more interpretable, while Logistic Regression might be computationally more efficient for large datasets.
#
# - Comparison of Base Model with Ensemble Model: DT vs RF
#
# Both models achieved perfect accuracy. Random Forest might offer better generalization and robustness due to its ensemble nature, but it might also be computationally more expensive than a single Decision Tree.

# %% [markdown]
# Model Run Statistics
#
# - Time Taken:
#
# Decision Tree and Stochastic Gradient Descent had the fastest training times.
# KNN and XGBoost took slightly longer to train.
#
# SVM, Logistic Regression, and Random Forest had training times in the middle range.
#
# - Memory Usage:
#
# Stochastic Gradient Descent and Decision Tree had the lowest memory usage.
# Support Vector Machine had the highest memory usage. Other models had moderate memory usage.
#
# Overall
#
# The cross-validation results demonstrate excellent performance for the model. The high accuracy across all folds suggests that the model is robust and generalizes well to unseen data.
#
# Model Comparison
#
# Accuracy: All models achieved perfect accuracy in this case.
#
# Training Time: Decision Tree and SGD were the fastest, while SVM and XGBoost were slightly slower.
#
# Memory Usage: SGD and Decision Tree had the lowest memory usage, while SVM had the highest.
#
# Considerations
#
# Data Size and Complexity: The performance and resource requirements of different models can vary depending on the size and complexity of the dataset.
#
# Hyperparameter Tuning: The performance of some models (e.g., SVM, XGBoost) can be further improved through careful hyperparameter tuning.
#
# Interpretability: Some models (e.g., Decision Trees) are more interpretable than others, making it easier to understand the decision-making process.
#
# - Inherent Complexity
#
# Decision Tree and Stochastic Gradient Descent are likely less complex models compared to others.
#
# K-Nearest Neighbors appears to be the most complex model among those considered, requiring the most time for training.
#
# SVM, Random Forest, and XGBoost have moderate complexity levels, falling between the simple and complex models.

# %% [markdown]
# Observations | Findings
#
# i. Classification of Dataset into {Segments | Clusters | Classes} using Supervised Learning Classification Algorithms
#
# - Decision Tree: Achieved perfect accuracy (1.00), indicating that the model successfully classified all instances into their respective classes.
# - Random Forest: Also achieved perfect accuracy (1.00), demonstrating high classification accuracy.
# - Logistic Regression: Achieved perfect accuracy (1.00), suggesting effective classification.
# - Other Models: SVM, SGD, KNN, and Naive Bayes achieved moderate accuracy levels, indicating some misclassifications.
#
# ii. Identification of {Important | Contributing | Significant} Variables or Features and their Thresholds for Classification
#
# - Feature Importance from Random Forest: The feature importance plot for the Random Forest model revealed that 'Category_code' was the most significant feature influencing the classification. This indicates that the 'Category_code' variable played a crucial role in determining the class of each instance.
#
# - Thresholds for Classification (Based on Decision Tree Visualization): The Decision Tree visualization provides insights into the decision boundaries and potential thresholds for classification.
# Each node in the tree represents a decision based on a specific feature (in this case, 'Category_code'). The threshold values for 'Category_code' at each node (e.g., 'Category_code <= 0.5', 'Category_code <= 1.5') can be considered as potential thresholds for classifying instances.
#
# - Interpretation: The high importance of 'Category_code' suggests that the classes within the dataset are likely strongly associated with different categories.
# The decision tree visualization provides a visual representation of how the model uses the 'Category_code' to make classification decisions.
#
# iii. Determination of an appropriate Classification Model based on Performance Metrics
#
# - Performance Metrics
#
# |Model	| Accuracy |	Precision |	Recall |	F1-score|
# |-------|----------|------------|--------|----------|
# |Logistic Regression |	1.00 |	1.00 |	1.00 |	1.00|
# |Support Vector Machine	|0.48	|0.48|	0.48|	0.48|
# |Stochastic Gradient Descent	|0.48|	0.48	|1.00	|0.65|
# |Decision Tree	|1.00|	1.00	|1.00|	1.00|
# |K-Nearest Neighbors|	0.49	|0.49|	0.49|	0.49|
# |Naive Bayes|	0.47	|0.41	|0.41|	0.41|
# |Random Forest|	1.00	|1.00	|1.00	|1.00|
# |XGBoost|	0.4963|	0.50|	0.50	|0.50|
#
# - Model Comparison
#
# Top Performers:
#
# Decision Tree and Random Forest achieved perfect accuracy (1.00) across all metrics, indicating exceptional performance.
# Logistic Regression also achieved perfect accuracy, suggesting strong predictive power.
#
# Moderate Performance:
#
# SVM, KNN, SGD, and XGBoost showed moderate performance with accuracy scores around 0.48-0.50. These models may require further tuning or feature engineering to improve their performance.
#
# - Model Selection
#
# Based on the performance metrics, Decision Tree and Random Forest appear to be the most suitable classification models for this dataset.
#
# Reasons
#
# They both achieved perfect accuracy, indicating high predictive power.
# They have demonstrated excellent performance across all evaluation metrics (precision, recall, F1-score).
#
# Considerations
#
# Interpretability: Decision Trees are generally more interpretable than Random Forests, as their decision-making process can be visualized and understood more easily.
# Computational Cost: Decision Trees typically have lower computational costs than Random Forests, especially for large datasets.
#
# Conclusion:
#
# High Performance of Decision Tree and Random Forest: These models achieved perfect accuracy (1.00), indicating strong predictive power and suggesting that the data might be relatively well-separated or the models have effectively captured the underlying patterns.
#
# Moderate Performance of Other Models: SVM, SGD, KNN, and XGBoost showed moderate accuracy, indicating that these models may require further tuning or feature engineering to improve their performance.
#
# Impact of Data Preprocessing: The application of scaling techniques (Standardization, Normalization, and potentially Log Transformation) likely played a crucial role in improving the performance of distance-based models like KNN. This suggests that careful data preprocessing is essential for achieving optimal model performance.
#
# Feature Importance: The 'Category_code' was identified as the most significant feature influencing classification, highlighting its importance in predicting the target variable.

# %% [markdown]
# Managerial Insights | Recommendations
#
# Preprocessing of Data
#
# - Recommended Treatment of Missing Data: The current approach seems reasonable.
# - Recommended Numerical Encoding of Non-Numeric Categorical Data: The high performance of the models suggests that the chosen encoding method (ordinal encoding) was effective.
# - Recommended Treatment of Non-Categorical Numeric Data: The application of standardization, normalization (Min-Max Scaling), and log transformation indicates a thorough approach to handling numerical data. These techniques likely played a crucial role in improving the performance of distance-based models like K-Nearest Neighbors.
#
# Supervised Machine Learning: Classification & Regression
#
# - Further explore hyperparameter tuning for each model to potentially improve performance.
# - Investigate feature engineering techniques to create new features or transform existing features to further enhance model accuracy and interpretability.
# - Consider deploying and monitoring the selected model in a real-world setting to evaluate its performance and make necessary adjustments over time.

# %% [markdown]
# CODES

# %% [markdown]
# #### Import Relevant Libraries

# %%
import pandas as pd, numpy as np                                                        # For Data Manipulation
import io                                                                               # For uploading live dataset
import requests                                                                         # For uploading live dataset
import scipy.stats as stats                                                             # Importing the stats module from scipy
from scipy.stats import skew, kurtosis                                                  # For descriptive stats of non-cat variables
from scipy.stats import spearmanr                                                       # For Spearman correlation
from scipy.stats import chi2_contingency                                                # For Chi-sq test
from scipy.stats import t                                                               # For T-test
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder                          # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder                                         # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer                                    # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler            # For Rescaling Data
from sklearn.model_selection import train_test_split                                    # For Splitting Data into Training & Testing Sets
import matplotlib.pyplot as plt                                                         # For data visualization
from matplotlib import pyplot as pp                                                     # For data visualization
import seaborn as sns                                                                   # For data visualization
from sklearn.linear_model import LogisticRegression                                     # For Logistic regression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score # For performance metrics
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree                 # For decision tree
from sklearn.ensemble import RandomForestClassifier                                     # For ensembling
from sklearn.model_selection import KFold, cross_val_score, cross_val_predict           # For cross validation
from sklearn.datasets import load_iris                                                  # For SVM
from sklearn.svm import SVC                                                             # Support Vector Classifier
from sklearn.linear_model import SGDClassifier                                          # Stochastic Gradient Descent
from sklearn.neighbors import KNeighborsClassifier                                      # For KNN
from sklearn.naive_bayes import GaussianNB                                              # Naive Bayes
import xgboost as xgb                                                                   # Extreme Gradient Boosting
import time                                                                             # For measuring time taken by models
from xgboost import XGBClassifier                                                       # XGBoost

# %% [markdown]
# #### Upload Live Dataset

# %%
# Google Drive File Link (URL) of Test Dataset
sg47_url = "https://drive.google.com/file/d/1nX-OYPadLCWTWIKG0qTP6GVs2C5aZP1r/view?usp=drive_link"

# Extract the File Id from the URL
sg47_file_id = sg47_url.split('/')[-2]

# Construct the Download URL
sg47_download_url = f"https://drive.google.com/uc?id={sg47_file_id}"

# Download the File Content
sg47_response = requests.get(sg47_download_url)
sg47_response.raise_for_status()                  # Raise an Exception for Bad Responses

# Read the Test Dataset
sg47_import_export_data = pd.read_csv(io.StringIO(sg47_response.text))

# Display Test Dataset Information
sg47_import_export_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   15000 non-null  object
#  1   Country          15000 non-null  object
#  2   Product          15000 non-null  object
#  3   Import_Export    15000 non-null  object
#  4   Quantity         15000 non-null  int64
#  5   Value            15000 non-null  float64
#  6   Date             15000 non-null  object
#  7   Category         15000 non-null  object
#  8   Port             15000 non-null  object
#  9   Customs_Code     15000 non-null  int64
#  10  Weight           15000 non-null  float64
#  11  Shipping_Method  15000 non-null  object
#  12  Supplier         15000 non-null  object
#  13  Customer         15000 non-null  object
#  14  Invoice_Number   15000 non-null  int64
#  15  Payment_Terms    15000 non-null  object
# ...

# %% [markdown]
# #### Creating Sample of 5001 records from Live Dataset

# %%
# Number of Records in Student Sample
sg47_num_of_records = 5001

# Create Permanent Random State using Last 4 Digits of Student Roll Number
sg47_random_state = 55047

# Create a Random Sample from the Test Dataset
sg47_sample_data = sg47_import_export_data.sample(n=sg47_num_of_records, random_state=sg47_random_state)

# Display Student Sample Information
sg47_sample_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5001 entries, 6176 to 9399
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   5001 non-null   object
#  1   Country          5001 non-null   object
#  2   Product          5001 non-null   object
#  3   Import_Export    5001 non-null   object
#  4   Quantity         5001 non-null   int64
#  5   Value            5001 non-null   float64
#  6   Date             5001 non-null   object
#  7   Category         5001 non-null   object
#  8   Port             5001 non-null   object
#  9   Customs_Code     5001 non-null   int64
#  10  Weight           5001 non-null   float64
#  11  Shipping_Method  5001 non-null   object
#  12  Supplier         5001 non-null   object
#  13  Customer         5001 non-null   object
#  14  Invoice_Number   5001 non-null   int64
#  15  Payment_Terms    5001 non-null   object
# dtypes: float64(2), int64(3), object(11)
# ...

# %%
# Dimensions of Sample Data
sg47_sample_data.shape
# Out:
# (5001, 16)

# %% [markdown]
# #### Data Bifurcation into Categorical and Non-Categorical Variables

# %%
from tabulate import tabulate

# Data for the table
sg47_table_values = [["Transaction_ID", "Index", ""],
        ["Country", "Categorical", "Nominal"],
        ["Product", "Categorical", "Nominal"],
              ["Import_Export", "Categorical", "Nominal"],
        ["Quantity", "Non-Categorical", ""],
        ["Value", "Non-Categorical", ""],
              ["Date", "Categorical", "Nominal"],
        ["Category", "Categorical", "Nominal"],
        ["Port", "Categorical", "Nominal"],
              ["Customs_Code", "Non-Categorical", ""],
        ["Weight", "Non-Categorical", ""],
        ["Shipping_Method", "Categorical", "Nominal"],
              ["Supplier", "Categorical", "Nominal"],
        ["Customer", "Categorical", "Nominal"],
        ["Invoice_Number", "Non-Categorical", ""],
               ["Payment_Terms", "Categorical", "Nominal"]]

# Column headers
sg47_headers = ["Variable", "Type", "Category"]

# Generate table
sg47_table = tabulate(sg47_table_values, headers=sg47_headers, tablefmt="grid")
print(sg47_table)
# Out:
# +-----------------+-----------------+------------+
# | Variable        | Type            | Category   |
# +=================+=================+============+
# | Transaction_ID  | Index           |            |
# +-----------------+-----------------+------------+
# | Country         | Categorical     | Nominal    |
# +-----------------+-----------------+------------+
# | Product         | Categorical     | Nominal    |
# +-----------------+-----------------+------------+
# | Import_Export   | Categorical     | Nominal    |
# +-----------------+-----------------+------------+
# | Quantity        | Non-Categorical |            |
# +-----------------+-----------------+------------+
# | Value           | Non-Categorical |            |
# +-----------------+-----------------+------------+
# | Date            | Categorical     | Nominal    |
# +-----------------+-----------------+------------+
# | Category        | Categorical     | Nominal    |
# ...

# %%
# Categorical Data [Nominal | Ordinal]
sg47_cat = sg47_sample_data[['Country', 'Product', 'Import_Export', 'Date', 'Category', 'Port',
                             'Shipping_Method', 'Supplier', 'Customer', 'Payment_Terms']]
sg47_cat
# Out:
#                                  Country   Product Import_Export        Date  \
# 6176                             Liberia  security        Import  31-03-2024
# 6390                             Mayotte     voice        Export  27-01-2022
# 8576                              Brazil      help        Import  30-08-2022
# 4228                               Qatar      rich        Import  01-04-2024
# 3266                             Ukraine      want        Export  03-05-2023
# ...                                  ...       ...           ...         ...
# 753                              Ecuador    design        Export  12-04-2021
# 5868   Heard Island and McDonald Islands       job        Export  07-01-2024
# 7185                              Kuwait  material        Import  08-08-2024
# 14417                              Italy  politics        Import  25-02-2024
# 9399                               Tonga    option        Export  09-08-2024
#
# ...

# %%
# Non-Categorical Data
sg47_non_cat = sg47_sample_data[['Quantity', 'Value', 'Customs_Code', 'Weight', 'Invoice_Number']]
sg47_non_cat
# Out:
#        Quantity    Value  Customs_Code   Weight  Invoice_Number
# 6176        401  9673.61        826949   746.38        55741094
# 6390       6900  7811.11        546118   831.56        37758597
# 8576       5162  4765.79        221498  4321.26        48060373
# 4228       9993  5070.10        160191   199.86        44653867
# 3266       2344  4089.75        940425  1116.14        41668843
# ...         ...      ...           ...      ...             ...
# 753         659  9861.74        919154  3192.11         8766838
# 5868       1756  7690.28        367415   522.16        36992570
# 7185       4263  5837.19        682842   474.43        29002814
# 14417        68   143.96        941984  2627.18         9467432
# 9399       6650  3642.95        708429   767.49        73738963
#
# [5001 rows x 5 columns]

# %% [markdown]
# ### __Data Preprocessing__
# #### Treatment of Missing Data

# %%
# Missing Data Information
sg47_sample_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5001 entries, 6176 to 9399
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   5001 non-null   object
#  1   Country          5001 non-null   object
#  2   Product          5001 non-null   object
#  3   Import_Export    5001 non-null   object
#  4   Quantity         5001 non-null   int64
#  5   Value            5001 non-null   float64
#  6   Date             5001 non-null   object
#  7   Category         5001 non-null   object
#  8   Port             5001 non-null   object
#  9   Customs_Code     5001 non-null   int64
#  10  Weight           5001 non-null   float64
#  11  Shipping_Method  5001 non-null   object
#  12  Supplier         5001 non-null   object
#  13  Customer         5001 non-null   object
#  14  Invoice_Number   5001 non-null   int64
#  15  Payment_Terms    5001 non-null   object
# dtypes: float64(2), int64(3), object(11)
# ...

# %%
# Variable-wise Missing Data Information
sg47_variable_missing_data = sg47_sample_data.isna().sum(); sg47_variable_missing_data
# Out:
# Transaction_ID     0
# Country            0
# Product            0
# Import_Export      0
# Quantity           0
# Value              0
# Date               0
# Category           0
# Port               0
# Customs_Code       0
# Weight             0
# Shipping_Method    0
# Supplier           0
# Customer           0
# Invoice_Number     0
# Payment_Terms      0
# dtype: int64

# %%
# Record-wise Missing Data Information
sg47_record_missing_data = sg47_sample_data.isna().sum(axis=1).sort_values(ascending=False).head(); sg47_record_missing_data
# Out:
# 6176     0
# 8728     0
# 6088     0
# 14433    0
# 83       0
# dtype: int64

# %% [markdown]
# ##### __Automated Code for Missing Data Handling__

# %%
# Function to handle missing data dynamically with summary statistics
def handle_missing_data(sg47_sample_data, threshold=0.5, strategy='median'):
    """
    Handles missing data in a DataFrame by either removing columns/rows with >threshold% missing values
    or imputing the missing values using the specified strategy. Also provides summary statistics.

    Parameters:
        sg47_sample_data (pd.DataFrame): Input DataFrame.
        threshold (float): Threshold for removing columns/rows (default: 0.5).
        strategy (str): Imputation strategy ('mean', 'median', or 'mode').

    Returns:
        pd.DataFrame: DataFrame after handling missing data.
    """
    # Summary statistics for missing data (Columns)
    sg47_missing_count_col = sg47_sample_data.isnull().sum()
    sg47_missing_percentage_col = (sg47_missing_count_col / len(sg47_sample_data)) * 100
    sg47_missing_summary_col = pd.DataFrame({
        'Missing Count': sg47_missing_count_col,
        'Missing Percentage': sg47_missing_percentage_col
    })
    print("Missing Data Summary (Columns):")
    print(sg47_missing_summary_col)

    # Summary statistics for missing data (Rows)
    sg47_missing_count_row = sg47_sample_data.isnull().sum(axis=1)
    sg47_missing_percentage_row = (sg47_missing_count_row / len(sg47_sample_data.columns)) * 100
    sg47_missing_summary_row = pd.DataFrame({
        'Missing Count': sg47_missing_count_row,
        'Missing Percentage': sg47_missing_percentage_row
    }, index=sg47_sample_data.index)  # Use original DataFrame index
    print("\nMissing Data Summary (Rows):")
    print(sg47_missing_summary_row)

    # Step 1: Drop columns with missing data > threshold
    sg47_columns_to_drop = sg47_missing_percentage_col[sg47_missing_percentage_col > threshold * 100].index
    sg47_sample_data = sg47_sample_data.drop(columns=sg47_columns_to_drop)
    print(f"\nDropped columns with >{threshold * 100}% missing values: {list(sg47_columns_to_drop)}")

    # Step 2: Drop rows with missing data > threshold
    sg47_row_missing_percentage = sg47_sample_data.isnull().mean(axis=1)
    sg47_rows_to_drop = sg47_row_missing_percentage[sg47_row_missing_percentage > threshold].index
    sg47_sample_data = sg47_sample_data.drop(index=sg47_rows_to_drop)
    print(f"Dropped rows with >{threshold * 100}% missing values: {list(sg47_rows_to_drop)}")

    # Step 3: Impute remaining missing values based on the strategy
    for col in sg47_sample_data.columns:
        if sg47_sample_data[col].isnull().sum() > 0:
            if strategy == 'mean' and pd.api.types.is_numeric_dtype(sg47_sample_data[col]):
                sg47_sample_data[col] = sg47_sample_data[col].fillna(sg47_sample_data[col].mean())
            elif strategy == 'median' and pd.api.types.is_numeric_dtype(sg47_sample_data[col]):
                sg47_sample_data[col] = sg47_sample_data[col].fillna(sg47_sample_data[col].median())
            elif strategy == 'mode':
                sg47_sample_data[col] = sg47_sample_data[col].fillna(sg47_sample_data[col].mode()[0])  # Mode always returns the first mode value
            print(f"Imputed missing values in column '{col}' using '{strategy}'")

    return sg47_sample_data


sg47_cleaned_data = handle_missing_data(sg47_sample_data, threshold=0.5, strategy='median')
sg47_cleaned_data
# Out:
# Missing Data Summary (Columns):
#                  Missing Count  Missing Percentage
# Transaction_ID               0                 0.0
# Country                      0                 0.0
# Product                      0                 0.0
# Import_Export                0                 0.0
# Quantity                     0                 0.0
# Value                        0                 0.0
# Date                         0                 0.0
# Category                     0                 0.0
# Port                         0                 0.0
# Customs_Code                 0                 0.0
# Weight                       0                 0.0
# Shipping_Method              0                 0.0
# Supplier                     0                 0.0
# Customer                     0                 0.0
# Invoice_Number               0                 0.0
# Payment_Terms                0                 0.0
#
# Missing Data Summary (Rows):
# ...

# %% [markdown]
# #### Numerical Encoding of Non-Numeric Categorical Data

# %%
# Using Scikit Learn : Ordinal Encoder (Superior)
sg47_oe = OrdinalEncoder()

# Apply OrdinalEncoder on each column
sg47_oe_fit1 = sg47_oe.fit_transform(sg47_cat[['Import_Export']])
sg47_oe_fit2 = sg47_oe.fit_transform(sg47_cat[['Category']])
sg47_oe_fit3 = sg47_oe.fit_transform(sg47_cat[['Shipping_Method']])
sg47_oe_fit4 = sg47_oe.fit_transform(sg47_cat[['Payment_Terms']])

# Create DataFrames for encoded columns
sg47_encoded1 = pd.DataFrame(sg47_oe_fit1, columns=['Import_Export_code'])
sg47_encoded2 = pd.DataFrame(sg47_oe_fit2, columns=['Category_code'])
sg47_encoded3 = pd.DataFrame(sg47_oe_fit3, columns=['Shipping_Method_code'])
sg47_encoded4 = pd.DataFrame(sg47_oe_fit4, columns=['Payment_Terms_code'])

# Reset the index of each DataFrame to ensure alignment
sg47_encoded1.reset_index(drop=True, inplace=True)
sg47_encoded2.reset_index(drop=True, inplace=True)
sg47_encoded3.reset_index(drop=True, inplace=True)
sg47_encoded4.reset_index(drop=True, inplace=True)

# Concatenate the new encoded columns
sg47_encoded_codes = pd.concat([
    sg47_encoded1,
    sg47_encoded2,
    sg47_encoded3,
    sg47_encoded4], axis=1)

# Join the sample with the encoded columns
sg47_cat_codes = sg47_sample_data.reset_index(drop=True).join(sg47_encoded_codes)
sg47_cat_codes
# Out:
#                             Transaction_ID                            Country  \
# 0     3b2f3a90-9ff1-4d89-b7d6-a6e851856779                            Liberia
# 1     cb578ed4-b637-4a3f-9187-9458530d14f2                            Mayotte
# 2     4c9455c3-e9d1-49ed-994a-b08d54f41e7c                             Brazil
# 3     37599b77-ce1b-4150-9154-17a8ee61157c                              Qatar
# 4     13169396-7edd-45ba-a901-cb3a82132bfe                            Ukraine
# ...                                    ...                                ...
# 4996  eed15368-5811-4722-a77d-fc7b722c353d                            Ecuador
# 4997  bd922f27-954e-4d4b-bc1b-6a78400c3b33  Heard Island and McDonald Islands
# 4998  7e75ca6b-c753-4266-a47a-7c521beb1c5a                             Kuwait
# 4999  3523e2e8-4e72-4aea-b2a4-f184920ed19f                              Italy
# 5000  670e490d-84c7-4c4f-91f5-9f5db011cc5f                              Tonga
#
# ...

# %% [markdown]
# ##### __Encoded Codes:__
# **Import_Export** : Export = 0, Import = 1
#
# **Category** : Clothing = 0, Electronics = 1, Furniture = 2, Machine = 3, Toys = 4
#
# **Shipping_Method** : Air = 0, Land = 1, Sea =2
#
# **Payment_Terms** : Cash on Delivery = 0, Net 30 = 1, Net 60 = 2, Prepaid = 3

# %%
# Summary of all encoded codes
sg47_encoded_codes
# Out:
#       Import_Export_code  Category_code  Shipping_Method_code  \
# 0                    1.0            0.0                   2.0
# 1                    0.0            3.0                   0.0
# 2                    1.0            0.0                   0.0
# 3                    1.0            1.0                   1.0
# 4                    0.0            2.0                   0.0
# ...                  ...            ...                   ...
# 4996                 0.0            1.0                   0.0
# 4997                 0.0            1.0                   0.0
# 4998                 1.0            0.0                   2.0
# 4999                 1.0            0.0                   2.0
# 5000                 0.0            3.0                   1.0
#
#       Payment_Terms_code
# 0                    2.0
# 1                    2.0
# 2                    1.0
# 3                    2.0
# 4                    1.0
# ...                  ...
# 4996                 1.0
# ...

# %% [markdown]
# #### Re-Scaling & Transformation of Numeric Data (Treatment of Data having Outliers)

# %% [markdown]
# #### _Standardization_

# %%
# Histogram before re-scaling
plt.figure(figsize=(8, 6))
sns.histplot(sg47_non_cat[['Quantity', 'Value', 'Weight']], kde=True)  # kde=True adds the Kernel Density Estimate curve
plt.title('Histogram before Re-scaling (for Quantity, Value, Weight)')
plt.show()

# %%
# Initialize the StandardScaler
sg47_ss = StandardScaler()

# Fit and transform the selected columns
sg47_ss_fit = sg47_ss.fit_transform(sg47_non_cat[['Quantity', 'Value', 'Weight']])

# Create a DataFrame with standardized columns
sg47_noncat_std = pd.DataFrame(sg47_ss_fit, columns=['Quantity_std', 'Value_std', 'Weight_std'], index=sg47_non_cat.index)

# Concatenate the standardized columns back into the original non-categorical dataset
sg47_noncat_std_combined = pd.concat([sg47_non_cat, sg47_noncat_std], axis=1)

# Display the updated DataFrame
sg47_noncat_std_combined
# Out:
#        Quantity    Value  Customs_Code   Weight  Invoice_Number  Quantity_std  \
# 6176        401  9673.61        826949   746.38        55741094     -1.599139
# 6390       6900  7811.11        546118   831.56        37758597      0.661358
# 8576       5162  4765.79        221498  4321.26        48060373      0.056843
# 4228       9993  5070.10        160191   199.86        44653867      1.737173
# 3266       2344  4089.75        940425  1116.14        41668843     -0.923320
# ...         ...      ...           ...      ...             ...           ...
# 753         659  9861.74        919154  3192.11         8766838     -1.509401
# 5868       1756  7690.28        367415   522.16        36992570     -1.127840
# 7185       4263  5837.19        682842   474.43        29002814     -0.255849
# 14417        68   143.96        941984  2627.18         9467432     -1.714964
# 9399       6650  3642.95        708429   767.49        73738963      0.574403
#
#        Value_std  Weight_std
# ...

# %% [markdown]
# #### _Normalization (Min-Max Scaling)_

# %%
# Initialize the MinMaxScaler
sg47_mms = MinMaxScaler()

# Fit and transform the selected columns
sg47_mms_fit = sg47_mms.fit_transform(sg47_non_cat[['Quantity', 'Value', 'Weight']])

# Create a DataFrame with MinMax normalized columns
sg47_noncat_minmax_norm = pd.DataFrame(sg47_mms_fit, columns=['Quantity_mmnorm', 'Value_mmnorm', 'Weight_mmnorm'], index=sg47_non_cat.index)

# Concatenate the normalized columns back into the original non-categorical dataset
sg47_noncat_mmn_combined = pd.concat([sg47_non_cat, sg47_noncat_minmax_norm], axis=1)

# Display the updated DataFrame
sg47_noncat_mmn_combined
# Out:
#        Quantity    Value  Customs_Code   Weight  Invoice_Number  \
# 6176        401  9673.61        826949   746.38        55741094
# 6390       6900  7811.11        546118   831.56        37758597
# 8576       5162  4765.79        221498  4321.26        48060373
# 4228       9993  5070.10        160191   199.86        44653867
# 3266       2344  4089.75        940425  1116.14        41668843
# ...         ...      ...           ...      ...             ...
# 753         659  9861.74        919154  3192.11         8766838
# 5868       1756  7690.28        367415   522.16        36992570
# 7185       4263  5837.19        682842   474.43        29002814
# 14417        68   143.96        941984  2627.18         9467432
# 9399       6650  3642.95        708429   767.49        73738963
#
#        Quantity_mmnorm  Value_mmnorm  Weight_mmnorm
# 6176          0.039836      0.967109       0.148941
# 6390          0.690321      0.778921       0.165984
# ...

# %% [markdown]
# #### _Log Transformation_

# %%
# Create a copy of the non-categorical DataFrame
sg47_lt = sg47_non_cat.copy()

# Apply log transformation to the selected columns
sg47_lt[['Quantity_lt', 'Value_lt', 'Weight_lt']] = sg47_lt[['Quantity', 'Value', 'Weight']].apply(np.log)

# Display the DataFrame with log-transformed columns
sg47_lt
# Out:
#        Quantity    Value  Customs_Code   Weight  Invoice_Number  Quantity_lt  \
# 6176        401  9673.61        826949   746.38        55741094     5.993961
# 6390       6900  7811.11        546118   831.56        37758597     8.839277
# 8576       5162  4765.79        221498  4321.26        48060373     8.549079
# 4228       9993  5070.10        160191   199.86        44653867     9.209640
# 3266       2344  4089.75        940425  1116.14        41668843     7.759614
# ...         ...      ...           ...      ...             ...          ...
# 753         659  9861.74        919154  3192.11         8766838     6.490724
# 5868       1756  7690.28        367415   522.16        36992570     7.470794
# 7185       4263  5837.19        682842   474.43        29002814     8.357728
# 14417        68   143.96        941984  2627.18         9467432     4.219508
# 9399       6650  3642.95        708429   767.49        73738963     8.802372
#
#        Value_lt  Weight_lt
# ...

# %% [markdown]
# ##### Final Preprocessed Subset

# %%
# Reset indices or align indices before joining
sg47_encoded_codes.reset_index(drop=True, inplace=True)
sg47_noncat_minmax_norm.reset_index(drop=True, inplace=True)

# Join the DataFrames
sg47_ppd = sg47_encoded_codes.join(sg47_noncat_minmax_norm)
sg47_ppd
# Out:
#       Import_Export_code  Category_code  Shipping_Method_code  \
# 0                    1.0            0.0                   2.0
# 1                    0.0            3.0                   0.0
# 2                    1.0            0.0                   0.0
# 3                    1.0            1.0                   1.0
# 4                    0.0            2.0                   0.0
# ...                  ...            ...                   ...
# 4996                 0.0            1.0                   0.0
# 4997                 0.0            1.0                   0.0
# 4998                 1.0            0.0                   2.0
# 4999                 1.0            0.0                   2.0
# 5000                 0.0            3.0                   1.0
#
#       Payment_Terms_code  Quantity_mmnorm  Value_mmnorm  Weight_mmnorm
# 0                    2.0         0.039836      0.967109       0.148941
# 1                    2.0         0.690321      0.778921       0.165984
# ...

# %%
# Histogram after re-scaling
plt.figure(figsize=(8, 6))
sns.histplot(sg47_ppd, kde=True)  # kde=True adds the Kernel Density Estimate curve
plt.title('Histogram after Re-scaling')
plt.show()

# %% [markdown]
# ### __Descriptive Statistics__

# %%
sg47_sample_data.describe()                          # No Meaningful Information regarding Categorical Variables
# Out:
#           Quantity        Value   Customs_Code       Weight  Invoice_Number
# count  5001.000000  5001.000000    5001.000000  5001.000000    5.001000e+03
# mean   4998.574285  5020.482985  550570.441112  2482.368252    5.035839e+07
# std    2875.318150  2860.494144  261242.262648  1444.001213    2.874674e+07
# min       3.000000   102.120000  100229.000000     1.980000    4.202600e+04
# 25%    2533.000000  2560.760000  326239.000000  1238.010000    2.571949e+07
# 50%    4976.000000  4997.170000  548179.000000  2474.040000    5.023911e+07
# 75%    7513.000000  7523.600000  775125.000000  3713.860000    7.496102e+07
# max    9994.000000  9999.130000  999964.000000  4999.930000    9.999799e+07

# %% [markdown]
# #### _Categorical Variable [Nominal | Ordinal]_
# ##### Count Statistics | Frequency | Proportion

# %%
# 'Country'
sg47_country_stats = pd.concat([sg47_sample_data['Country'].value_counts(), sg47_sample_data['Country'].value_counts(normalize=True).mul(100).round(2)],
                               axis=1, keys=('Count','Percentage')).reset_index()
sg47_country_stats
# Out:
#                                           Country  Count  Percentage
# 0                                           Congo     48        0.96
# 1                                           Korea     36        0.72
# 2                                         Bahamas     34        0.68
# 3                                      Martinique     33        0.66
# 4                                Pitcairn Islands     32        0.64
# ..                                            ...    ...         ...
# 238                               Kyrgyz Republic     11        0.22
# 239                                          Guam     11        0.22
# 240                                         Macao     11        0.22
# 241                                        Panama     11        0.22
# 242  South Georgia and the South Sandwich Islands     11        0.22
#
# [243 rows x 3 columns]

# %%
# 'Product'
sg47_product_stats = pd.concat([sg47_sample_data['Product'].value_counts(), sg47_sample_data['Product'].value_counts(normalize=True).mul(100).round(2)],
                               axis=1, keys=('Count','Percentage')).reset_index()
sg47_product_stats
# Out:
#        Product  Count  Percentage
# 0       family     15        0.30
# 1           Mr     13        0.26
# 2    important     12        0.24
# 3         card     12        0.24
# 4       behind     12        0.24
# ..         ...    ...         ...
# 962     inside      1        0.02
# 963      today      1        0.02
# 964       fast      1        0.02
# 965     create      1        0.02
# 966     common      1        0.02
#
# [967 rows x 3 columns]

# %%
# 'Import_Export'
sg47_imp_exp_stats = pd.concat([sg47_sample_data['Import_Export'].value_counts(), sg47_sample_data['Import_Export'].value_counts(normalize=True).mul(100).round(2)],
                               axis=1, keys=('Count','Percentage')).reset_index()
sg47_imp_exp_stats
# Out:
#   Import_Export  Count  Percentage
# 0        Import   2544       50.87
# 1        Export   2457       49.13

# %%
# 'Date'
sg47_date_stats = pd.concat([sg47_sample_data['Date'].value_counts(), sg47_sample_data['Date'].value_counts(normalize=True).mul(100).round(2)],
                               axis=1, keys=('Count','Percentage')).reset_index()
sg47_date_stats
# Out:
#             Date  Count  Percentage
# 0     15-02-2024     10        0.20
# 1     11-06-2022      9        0.18
# 2     21-05-2021      9        0.18
# 3     08-02-2021      9        0.18
# 4     29-12-2022      8        0.16
# ...          ...    ...         ...
# 1703  27-04-2020      1        0.02
# 1704  06-11-2023      1        0.02
# 1705  09-06-2023      1        0.02
# 1706  12-08-2023      1        0.02
# 1707  09-10-2023      1        0.02
#
# [1708 rows x 3 columns]

# %%
# 'Category'
sg47_category_stats = pd.concat([sg47_sample_data['Category'].value_counts(), sg47_sample_data['Category'].value_counts(normalize=True).mul(100).round(2)],
                               axis=1, keys=('Count','Percentage')).reset_index()
sg47_category_stats
# Out:
#       Category  Count  Percentage
# 0     Clothing   1052       21.04
# 1  Electronics   1020       20.40
# 2    Furniture    984       19.68
# 3    Machinery    982       19.64
# 4         Toys    963       19.26

# %%
# 'Port'
sg47_port_stats = pd.concat([sg47_sample_data['Port'].value_counts(), sg47_sample_data['Port'].value_counts(normalize=True).mul(100).round(2)],
                               axis=1, keys=('Count','Percentage')).reset_index()
sg47_port_stats
# Out:
#                    Port  Count  Percentage
# 0          Lake Michael      7        0.14
# 1          West Michael      7        0.14
# 2            Port Jason      6        0.12
# 3     North Christopher      6        0.12
# 4            Port David      6        0.12
# ...                 ...    ...         ...
# 4252         Pamelafurt      1        0.02
# 4253      North Caitlin      1        0.02
# 4254     Port Karenview      1        0.02
# 4255   East Jonathanton      1        0.02
# 4256         Josephbury      1        0.02
#
# [4257 rows x 3 columns]

# %%
# 'Shipping_Method'
sg47_shipping_stats = pd.concat([sg47_sample_data['Shipping_Method'].value_counts(), sg47_sample_data['Shipping_Method'].value_counts(normalize=True).mul(100).round(2)],
                               axis=1, keys=('Count','Percentage')).reset_index()
sg47_shipping_stats
# Out:
#   Shipping_Method  Count  Percentage
# 0            Land   1673       33.45
# 1             Sea   1666       33.31
# 2             Air   1662       33.23

# %%
# 'Supplier'
sg47_supplier_stats = pd.concat([sg47_sample_data['Supplier'].value_counts(), sg47_sample_data['Supplier'].value_counts(normalize=True).mul(100).round(2)],
                               axis=1, keys=('Count','Percentage')).reset_index()
sg47_supplier_stats
# Out:
#                             Supplier  Count  Percentage
# 0                        Johnson PLC      9        0.18
# 1                        Jones Group      8        0.16
# 2                        Johnson Inc      7        0.14
# 3                          Smith Inc      6        0.12
# 4                         Miller Inc      6        0.12
# ...                              ...    ...         ...
# 4561      Garcia, Osborne and Wright      1        0.02
# 4562  Stephens, Freeman and Reynolds      1        0.02
# 4563                  Mullins-Holmes      1        0.02
# 4564                       Rojas Inc      1        0.02
# 4565                   Ward-Erickson      1        0.02
#
# [4566 rows x 3 columns]

# %%
# 'Customer'
sg47_customer_stats = pd.concat([sg47_sample_data['Customer'].value_counts(), sg47_sample_data['Customer'].value_counts(normalize=True).mul(100).round(2)],
                               axis=1, keys=('Count','Percentage')).reset_index()
sg47_customer_stats
# Out:
#               Customer  Count  Percentage
# 0        Michael Jones      4        0.08
# 1         John Ramirez      4        0.08
# 2         Robert Jones      4        0.08
# 3         Ashley Black      3        0.06
# 4     Michael Williams      3        0.06
# ...                ...    ...         ...
# 4830     Robert Rogers      1        0.02
# 4831        Joyce Pope      1        0.02
# 4832   Victoria Wilson      1        0.02
# 4833     Susan Andrade      1        0.02
# 4834    Harry Lawrence      1        0.02
#
# [4835 rows x 3 columns]

# %%
# 'Payment_Terms'
sg47_pay_stats = pd.concat([sg47_sample_data['Payment_Terms'].value_counts(), sg47_sample_data['Payment_Terms'].value_counts(normalize=True).mul(100).round(2)],
                               axis=1, keys=('Count','Percentage')).reset_index()
sg47_pay_stats
# Out:
#       Payment_Terms  Count  Percentage
# 0  Cash on Delivery   1280       25.59
# 1            Net 60   1252       25.03
# 2           Prepaid   1245       24.90
# 3            Net 30   1224       24.48

# %% [markdown]
# ##### Minimum | Maximum | Mode | Rank

# %%
# 'Country'
sg47_country_min = sg47_sample_data['Country'].min()
sg47_country_max = sg47_sample_data['Country'].max()
sg47_country_mode = sg47_sample_data['Country'].mode()[0]
sg47_country_rank = sg47_sample_data['Country'].value_counts().rank(method='min', ascending=False)

print('Minimum Country:',sg47_country_min)
print('Maximum Country:',sg47_country_max)
print('Mode Country:',sg47_country_mode)
print('Rank:',sg47_country_rank)
# Out:
# Minimum Country: Afghanistan
# Maximum Country: Zimbabwe
# Mode Country: Congo
# Rank: Country
# Congo                                             1.0
# Korea                                             2.0
# Bahamas                                           3.0
# Martinique                                        4.0
# Pitcairn Islands                                  5.0
#                                                 ...
# Kyrgyz Republic                                 239.0
# Guam                                            239.0
# Macao                                           239.0
# Panama                                          239.0
# South Georgia and the South Sandwich Islands    239.0
# Name: count, Length: 243, dtype: float64

# %%
# 'Product'
sg47_product_min = sg47_sample_data['Product'].min()
sg47_product_max = sg47_sample_data['Product'].max()
sg47_product_mode = sg47_sample_data['Product'].mode()[0]
sg47_product_rank = sg47_sample_data['Product'].value_counts().rank(method='min', ascending=False)

print('Minimum Product:',sg47_product_min)
print('Maximum Product:',sg47_product_max)
print('Mode Product:',sg47_product_mode)
print('Rank:',sg47_product_rank)
# Out:
# Minimum Product: American
# Maximum Product: yourself
# Mode Product: family
# Rank: Product
# family         1.0
# Mr             2.0
# important      3.0
# card           3.0
# behind         3.0
#              ...
# inside       943.0
# today        943.0
# fast         943.0
# create       943.0
# common       943.0
# Name: count, Length: 967, dtype: float64

# %%
# 'Import_Export'
sg47_imp_exp_min = sg47_sample_data['Import_Export'].min()
sg47_imp_exp_max = sg47_sample_data['Import_Export'].max()
sg47_imp_exp_mode = sg47_sample_data['Import_Export'].mode()[0]
sg47_imp_exp_rank = sg47_sample_data['Import_Export'].value_counts().rank(method='min', ascending=False)

print('Minimum Import_Export:',sg47_imp_exp_min)
print('Maximum Import_Export:',sg47_imp_exp_max)
print('Mode Import_Export:',sg47_imp_exp_mode)
print('Rank:',sg47_imp_exp_rank)
# Out:
# Minimum Import_Export: Export
# Maximum Import_Export: Import
# Mode Import_Export: Import
# Rank: Import_Export
# Import    1.0
# Export    2.0
# Name: count, dtype: float64

# %%
# 'Date'
sg47_date_min = sg47_sample_data['Date'].min()
sg47_date_max = sg47_sample_data['Date'].max()
sg47_date_mode = sg47_sample_data['Date'].mode()[0]
sg47_date_rank = sg47_sample_data['Date'].value_counts().rank(method='min', ascending=False)

print('Minimum Date:',sg47_date_min)
print('Maximum Date:',sg47_date_max)
print('Mode Date:',sg47_date_mode)
print('Rank:',sg47_date_rank)
# Out:
# Minimum Date: 01-01-2020
# Maximum Date: 31-12-2023
# Mode Date: 15-02-2024
# Rank: Date
# 15-02-2024       1.0
# 11-06-2022       2.0
# 21-05-2021       2.0
# 08-02-2021       2.0
# 29-12-2022       5.0
#                ...
# 27-04-2020    1395.0
# 06-11-2023    1395.0
# 09-06-2023    1395.0
# 12-08-2023    1395.0
# 09-10-2023    1395.0
# Name: count, Length: 1708, dtype: float64

# %%
# 'Category'
sg47_category_min = sg47_sample_data['Category'].min()
sg47_category_max = sg47_sample_data['Category'].max()
sg47_category_mode = sg47_sample_data['Category'].mode()[0]
sg47_category_rank = sg47_sample_data['Category'].value_counts().rank(method='min', ascending=False)

print('Minimum Category:',sg47_category_min)
print('Maximum Category:',sg47_category_max)
print('Mode Category:',sg47_category_mode)
print('Rank:',sg47_category_rank)
# Out:
# Minimum Category: Clothing
# Maximum Category: Toys
# Mode Category: Clothing
# Rank: Category
# Clothing       1.0
# Electronics    2.0
# Furniture      3.0
# Machinery      4.0
# Toys           5.0
# Name: count, dtype: float64

# %%
# 'Port'
sg47_port_min = sg47_sample_data['Port'].min()
sg47_port_max = sg47_sample_data['Port'].max()
sg47_port_mode = sg47_sample_data['Port'].mode()[0]
sg47_port_rank = sg47_sample_data['Port'].value_counts().rank(method='min', ascending=False)

print('Minimum Port:',sg47_port_min)
print('Maximum Port:',sg47_port_max)
print('Mode Port:',sg47_port_mode)
print('Rank:',sg47_port_rank)
# Out:
# Minimum Port: Aaronmouth
# Maximum Port: Zhangborough
# Mode Port: Lake Michael
# Rank: Port
# Lake Michael           1.0
# West Michael           1.0
# Port Jason             3.0
# North Christopher      3.0
# Port David             3.0
#                      ...
# Pamelafurt           552.0
# North Caitlin        552.0
# Port Karenview       552.0
# East Jonathanton     552.0
# Josephbury           552.0
# Name: count, Length: 4257, dtype: float64

# %%
# 'Shipping_Method'
sg47_shipping_min = sg47_sample_data['Shipping_Method'].min()
sg47_shipping_max = sg47_sample_data['Shipping_Method'].max()
sg47_shipping_mode = sg47_sample_data['Shipping_Method'].mode()[0]
sg47_shipping_rank = sg47_sample_data['Shipping_Method'].value_counts().rank(method='min', ascending=False)

print('Minimum Shipping_Method:',sg47_shipping_min)
print('Maximum Shipping_Method:',sg47_shipping_max)
print('Mode Shipping_Method:',sg47_shipping_mode)
print('Rank:',sg47_shipping_rank)
# Out:
# Minimum Shipping_Method: Air
# Maximum Shipping_Method: Sea
# Mode Shipping_Method: Land
# Rank: Shipping_Method
# Land    1.0
# Sea     2.0
# Air     3.0
# Name: count, dtype: float64

# %%
# 'Supplier'
sg47_supplier_min = sg47_sample_data['Supplier'].min()
sg47_supplier_max = sg47_sample_data['Supplier'].max()
sg47_supplier_mode = sg47_sample_data['Supplier'].mode()[0]
sg47_supplier_rank = sg47_sample_data['Supplier'].value_counts().rank(method='min', ascending=False)

print('Minimum Supplier:',sg47_supplier_min)
print('Maximum Supplier:',sg47_supplier_max)
print('Mode Supplier:',sg47_supplier_mode)
print('Rank:',sg47_supplier_rank)
# Out:
# Minimum Supplier: Abbott LLC
# Maximum Supplier: Zuniga Ltd
# Mode Supplier: Johnson PLC
# Rank: Supplier
# Johnson PLC                         1.0
# Jones Group                         2.0
# Johnson Inc                         3.0
# Smith Inc                           4.0
# Miller Inc                          4.0
#                                   ...
# Garcia, Osborne and Wright        276.0
# Stephens, Freeman and Reynolds    276.0
# Mullins-Holmes                    276.0
# Rojas Inc                         276.0
# Ward-Erickson                     276.0
# Name: count, Length: 4566, dtype: float64

# %%
# 'Customer'
sg47_customer_min = sg47_sample_data['Customer'].min()
sg47_customer_max = sg47_sample_data['Customer'].max()
sg47_customer_mode = sg47_sample_data['Customer'].mode()[0]
sg47_customer_rank = sg47_sample_data['Customer'].value_counts().rank(method='min', ascending=False)

print('Minimum Customer:',sg47_customer_min)
print('Maximum Customer:',sg47_customer_max)
print('Mode Customer:',sg47_customer_mode)
print('Rank:',sg47_customer_rank)
# Out:
# Minimum Customer: Aaron Butler
# Maximum Customer: Zachary Wise
# Mode Customer: John Ramirez
# Rank: Customer
# Michael Jones         1.0
# John Ramirez          1.0
# Robert Jones          1.0
# Ashley Black          4.0
# Michael Williams      4.0
#                     ...
# Robert Rogers       148.0
# Joyce Pope          148.0
# Victoria Wilson     148.0
# Susan Andrade       148.0
# Harry Lawrence      148.0
# Name: count, Length: 4835, dtype: float64

# %%
# 'Payment_Terms'
sg47_pay_min = sg47_sample_data['Payment_Terms'].min()
sg47_pay_max = sg47_sample_data['Payment_Terms'].max()
sg47_pay_mode = sg47_sample_data['Payment_Terms'].mode()[0]
sg47_pay_rank = sg47_sample_data['Payment_Terms'].value_counts().rank(method='min', ascending=False)

print('Minimum Payment_Terms:',sg47_pay_min)
print('Maximum Payment_Terms:',sg47_pay_max)
print('Mode Payment_Terms:',sg47_pay_mode)
print('Rank:',sg47_pay_rank)
# Out:
# Minimum Payment_Terms: Cash on Delivery
# Maximum Payment_Terms: Prepaid
# Mode Payment_Terms: Cash on Delivery
# Rank: Payment_Terms
# Cash on Delivery    1.0
# Net 60              2.0
# Prepaid             3.0
# Net 30              4.0
# Name: count, dtype: float64

# %% [markdown]
# ##### Correlation (Spearman | Kendall)

# %%
# Spearman Correlation between Shipping_Method and Payment_Terms
sg47_spearman_corr1, sg47_p_value1 = stats.spearmanr(sg47_encoded_codes.iloc[:, 2], sg47_encoded_codes.iloc[:, 3])
print(f"Spearman Correlation between Shipping_Method and Payment_Terms: {sg47_spearman_corr1}, P-value: {sg47_p_value1}")
# Out:
# Spearman Correlation between Shipping_Method and Payment_Terms: 0.008758857107166064, P-value: 0.535742656473519

# %%
# Spearman Correlation between Import_Export and Shipping_Method
sg47_spearman_corr2, sg47_p_value2 = stats.spearmanr(sg47_encoded_codes.iloc[:, 0], sg47_encoded_codes.iloc[:, 2])
print(f"Spearman Correlation between Import_Export and Shipping_Method: {sg47_spearman_corr2}, P-value: {sg47_p_value2}")
# Out:
# Spearman Correlation between Import_Export and Shipping_Method: -0.0024727363805237094, P-value: 0.8612187901812222

# %%
# Kendall correlation between Import_Export and Payment_Terms
sg47_kendall_corr, sg47_p_value_kendall = stats.kendalltau(sg47_encoded_codes.iloc[:, 0], sg47_encoded_codes.iloc[:, 3])
print(f"Kendall Correlation between Import_Export and Payment_Terms: {sg47_kendall_corr}, P-value: {sg47_p_value_kendall}")
# Out:
# Kendall Correlation between Import_Export and Payment_Terms: -0.004021822099784538, P-value: 0.7554025435886975

# %% [markdown]
# #### _Non-Categorical Variable_

# %% [markdown]
# ##### Measures of Central Tendency {Minimum | Maximum | Mean | Median | Mode | Percentile}

# %% [markdown]
# ##### Measures of Dispersion {Range | Standard Deviation | Skewness | Kurtosis}

# %% [markdown]
# ##### Composite Measures {Coefficient of Variation | Confidence Interval}

# %%
sg47_noncat_descriptives = sg47_non_cat.describe()
sg47_noncat_descriptives
# Out:
#           Quantity        Value   Customs_Code       Weight  Invoice_Number
# count  5001.000000  5001.000000    5001.000000  5001.000000    5.001000e+03
# mean   4998.574285  5020.482985  550570.441112  2482.368252    5.035839e+07
# std    2875.318150  2860.494144  261242.262648  1444.001213    2.874674e+07
# min       3.000000   102.120000  100229.000000     1.980000    4.202600e+04
# 25%    2533.000000  2560.760000  326239.000000  1238.010000    2.571949e+07
# 50%    4976.000000  4997.170000  548179.000000  2474.040000    5.023911e+07
# 75%    7513.000000  7523.600000  775125.000000  3713.860000    7.496102e+07
# max    9994.000000  9999.130000  999964.000000  4999.930000    9.999799e+07

# %%
# Calculate Mode for each column
sg47_mode = sg47_non_cat.mode().iloc[0]

# Calculate Percentiles (25th, 50th, 75th)
sg47_percentiles = sg47_non_cat.quantile([0.25, 0.5, 0.75])

# Calculate Range (Max - Min) for each column
sg47_range = sg47_non_cat.max() - sg47_non_cat.min()

# Calculate Skewness for each column
sg47_skewness = sg47_non_cat.apply(skew)

# Calculate Kurtosis for each column
sg47_kurtosis = sg47_non_cat.apply(kurtosis)

# Calculate Coefficient of Variation (CV) for each column
sg47_cv = sg47_non_cat.std() / sg47_non_cat.mean()

# Calculate Confidence Interval (CI) for each column
sg47_n = 5001                 # Sample size
sg47_ci_lower = sg47_non_cat.mean() - 1.96 * (sg47_non_cat.std() / np.sqrt(sg47_n))
sg47_ci_upper = sg47_non_cat.mean() + 1.96 * (sg47_non_cat.std() / np.sqrt(sg47_n))

# Combine all of the above into a new DataFrame for easy addition to existing descriptives
sg47_summary_stats = pd.DataFrame({
    'Mode': sg47_mode,
    '25th Percentile': sg47_percentiles.loc[0.25],
    '50th Percentile': sg47_percentiles.loc[0.5],
    '75th Percentile': sg47_percentiles.loc[0.75],
    'Range': sg47_range,
    'Skewness': sg47_skewness,
    'Kurtosis': sg47_kurtosis,
    'Coefficient of Variation': sg47_cv,
    'CI Lower Bound': sg47_ci_lower,
    'CI Upper Bound': sg47_ci_upper
})

# Transpose the summary stats to add them as rows
sg47_summary_stats_transposed = sg47_summary_stats.T

# Concatenate the existing descriptive statistics with the new rows
sg47_descriptives_final = pd.concat([sg47_noncat_descriptives, sg47_summary_stats_transposed])
sg47_descriptives_final
# Out:
#                              Quantity        Value   Customs_Code  \
# count                     5001.000000  5001.000000    5001.000000
# mean                      4998.574285  5020.482985  550570.441112
# std                       2875.318150  2860.494144  261242.262648
# min                          3.000000   102.120000  100229.000000
# 25%                       2533.000000  2560.760000  326239.000000
# 50%                       4976.000000  4997.170000  548179.000000
# 75%                       7513.000000  7523.600000  775125.000000
# max                       9994.000000  9999.130000  999964.000000
# Mode                      1088.000000   241.830000  321741.000000
# 25th Percentile           2533.000000  2560.760000  326239.000000
# 50th Percentile           4976.000000  4997.170000  548179.000000
# 75th Percentile           7513.000000  7523.600000  775125.000000
# Range                     9991.000000  9897.010000  899735.000000
# ...

# %% [markdown]
# ##### Measures of Dispersion {Correlation (Pearson | Spearman)}

# %%
# Pearson Correlation
sg47_pearson_corr = sg47_non_cat.corr(method='pearson')
print("Pearson Correlation:")
sg47_pearson_corr
# Out:
# Pearson Correlation:
#                 Quantity     Value  Customs_Code    Weight  Invoice_Number
# Quantity        1.000000 -0.007698     -0.016250  0.017973       -0.015738
# Value          -0.007698  1.000000      0.010214  0.008844        0.023611
# Customs_Code   -0.016250  0.010214      1.000000 -0.015242       -0.003663
# Weight          0.017973  0.008844     -0.015242  1.000000        0.012572
# Invoice_Number -0.015738  0.023611     -0.003663  0.012572        1.000000

# %%
# Spearman Correlation
sg47_spearman_corr, _ = spearmanr(sg47_non_cat)
print("Spearman Correlation:")
print(sg47_spearman_corr)
# Out:
# Spearman Correlation:
# [[ 1.         -0.00780207 -0.01646726  0.01799474 -0.01533011]
#  [-0.00780207  1.          0.00999969  0.00851134  0.02369358]
#  [-0.01646726  0.00999969  1.         -0.015227   -0.0037868 ]
#  [ 0.01799474  0.00851134 -0.015227    1.          0.0120422 ]
#  [-0.01533011  0.02369358 -0.0037868   0.0120422   1.        ]]

# %% [markdown]
# ### __Data Visualization__
# #### _Basic Plots - Bar | Pie | Scatter | Line_

# %%
# Bar chart of Import_Export
sns.countplot(x='Import_Export', data=sg47_sample_data)
plt.title('Number of Imports/Exports')
plt.xticks(rotation=45)
plt.show()

# %%
# Horizontal bar chart of Category
sns.countplot(y='Category', data=sg47_sample_data)
plt.title('Number of Category')
plt.xlabel('Count')
plt.ylabel('Category')
plt.show()

# %%
# Group by Category and Import_Export to count occurrences
sg47_status_counts = sg47_sample_data.groupby(['Category', 'Import_Export']).size().unstack(fill_value=0)

# Extract data for the plot
sg47_categories = sg47_status_counts.index
sg47_import_counts = sg47_status_counts['Import']
sg47_export_counts = sg47_status_counts['Export']

# Create a stacked bar chart
sg47_x = np.arange(len(sg47_categories))

plt.bar(sg47_x, sg47_import_counts, width=0.5, label='Import', color='skyblue')
plt.bar(sg47_x, sg47_export_counts, width=0.5, bottom=sg47_import_counts, label='Export', color='orange')

# Add labels and title
plt.xlabel('Categories')
plt.ylabel('Counts')
plt.title('Counts of Import and Export by Category')
plt.xticks(sg47_x, sg47_categories)
plt.legend()

# Show the plot
plt.show()

# %%
# Pie chart
sg47_shipping_method_counts = sg47_sample_data['Shipping_Method'].value_counts()
plt.pie(sg47_shipping_method_counts, labels=sg47_shipping_method_counts.index, autopct='%1.1f%%')
plt.title('Distribution of Shipping Methods')
plt.show()

# %%
# Pie chart
sg47_payment_terms_counts = sg47_sample_data['Payment_Terms'].value_counts()
plt.pie(sg47_payment_terms_counts, labels=sg47_payment_terms_counts.index, autopct='%1.1f%%')
plt.title('Distribution of Payment Terms')
plt.show()

# %%
# Scatter plot
sns.scatterplot(x='Shipping_Method_code', y='Import_Export_code', data=sg47_ppd, hue='Quantity_mmnorm', palette='coolwarm', style='Payment_Terms_code', markers=["o", "s", "d", "v"])
plt.title('Shipping Method vs Import Export (By Quantity)', fontsize=14)
plt.xlabel('Shipping Method', fontsize=12)
plt.ylabel('Import Export', fontsize=12)
plt.legend(title='Scale:', loc='upper right')
plt.show()

# %%
pp.scatter(x='Shipping_Method', y='Quantity', data=sg47_sample_data, marker='s', c='Quantity', cmap='Spectral')
pp.xlabel('Shipping_Method')
pp.ylabel('Quantity')
pp.title('Shipping_Method vs Quantity Scatter Plot')
pp.colorbar()
pp.grid()
pp.show()

# %%
# Line Plot
sg47_category_line = sg47_ppd.groupby('Category_code')[['Quantity_mmnorm', 'Value_mmnorm']].sum()

# Creating the line plot
plt.figure(figsize=(10,6))
sns.lineplot(data=sg47_category_line, x=sg47_category_line.index, y='Quantity_mmnorm', label='Quantity', marker='o')
sns.lineplot(data=sg47_category_line, x=sg47_category_line.index, y='Value_mmnorm', label='Value', marker='o')

# Adding labels and title
plt.title('Total Quantity and Value by Category', fontsize=14)
plt.xlabel('Category', fontsize=12)
plt.ylabel('Total', fontsize=12)
plt.legend(title='Variables', loc='upper left')
plt.grid(True)
plt.show()

# %% [markdown]
# #### _Advance Plots -  Box-Whisker | Pair | Heat_

# %%
# Box plot
pp.boxplot([sg47_ppd.Category_code], meanline=True, showmeans=True, labels=['Category'], vert=True)
pp.title('Category Box Plot')
pp.show()

# %%
# Pair Plot
sg47_numerical_columns = ['Category_code', 'Shipping_Method_code', 'Payment_Terms_code']

# Creating pairplot
sns.pairplot(sg47_ppd[sg47_numerical_columns], kind='scatter', diag_kind='kde', plot_kws={'alpha':0.6})

# Show the plot
plt.suptitle('Pairplot of Encoded Variables', fontsize=16, y=1.02)
plt.show()

# %%
# Correlation heatmap for numerical variables
correlation_matrix = sg47_sample_data[['Quantity', 'Value', 'Weight']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### __Inferential Statistics__

# %% [markdown]
# #### _Categorical Variable [Nominal | Ordinal]_
# ##### Test of Homogeneity {Chi-sq}

# %%
# Contingency table
# Comparing 'Import_Export' and 'Shipping_Method'
sg47_contingency_table = pd.crosstab(sg47_sample_data['Import_Export'], sg47_sample_data['Shipping_Method'])

# Perform the Chi-Square test
sg47_chi2_stat, sg47_p_value, sg47_dof, sg47_expected = chi2_contingency(sg47_contingency_table)

# Print the results
print("Chi-Square Test of Homogeneity")
print(f"Chi-Square Statistic: {sg47_chi2_stat}")
print(f"P-Value: {sg47_p_value}")
print(f"Degrees of Freedom: {sg47_dof}")
print("\nExpected Frequencies:")
print(sg47_expected)

# Interpret the results
sg47_alpha = 0.05                 # Significance level
if sg47_p_value < sg47_alpha:
    print("\nResult: There is a significant difference in the distribution of 'Shipping_Method' across 'Import_Export'.")
else:
    print("\nResult: There is no significant difference in the distribution of 'Shipping_Method' across 'Import_Export'.")
# Out:
# Chi-Square Test of Homogeneity
# Chi-Square Statistic: 0.7294416761707467
# P-Value: 0.6943904711965323
# Degrees of Freedom: 2
#
# Expected Frequencies:
# [[816.5434913  821.94781044 818.50869826]
#  [845.4565087  851.05218956 847.49130174]]
#
# Result: There is no significant difference in the distribution of 'Shipping_Method' across 'Import_Export'.

# %% [markdown]
# #### _Non-Categorical Variable_

# %% [markdown]
# ##### Test of Normality {Shapiro-Wilk | Kolmogorov-Smirnov | Anderson-Darling | Jarque-Bera}

# %%
# Select the numerical variables from your dataset
sg47_numerical_data = sg47_sample_data[['Quantity', 'Value', 'Weight']]

# Define a function to perform all normality tests
def normality_tests(data):
    results = []

    for col in data.columns:
        # Shapiro-Wilk Test
        sg47_shapiro_stat, sg47_shapiro_p = stats.shapiro(data[col])

        # Kolmogorov-Smirnov Test
        sg47_ks_stat, sg47_ks_p = stats.kstest(data[col], 'norm', args=(data[col].mean(), data[col].std()))

        # Anderson-Darling Test
        sg47_ad_result = stats.anderson(data[col], dist='norm')

        # Jarque-Bera Test
        sg47_jb_stat, sg47_jb_p = stats.jarque_bera(data[col])

        # Store results
        results.append({
            'Variable': col,
            'Shapiro-Wilk (Statistic)': sg47_shapiro_stat,
            'Shapiro-Wilk (P-Value)': sg47_shapiro_p,
            'Kolmogorov-Smirnov (Statistic)': sg47_ks_stat,
            'Kolmogorov-Smirnov (P-Value)': sg47_ks_p,
            'Anderson-Darling (Statistic)': sg47_ad_result.statistic,
            'Anderson-Darling (Critical-Values)': sg47_ad_result.critical_values,
            'Anderson-Darling (Significance Levels)': sg47_ad_result.significance_level,
            'Jarque-Bera (Statistic)': sg47_jb_stat,
            'Jarque-Bera (P-Value)': sg47_jb_p
        })

    return pd.DataFrame(results)

# Perform normality tests
sg47_normality_results = normality_tests(sg47_numerical_data)

# Display the results
print(sg47_normality_results)
# Out:
#    Variable  Shapiro-Wilk (Statistic)  Shapiro-Wilk (P-Value)  \
# 0  Quantity                  0.956224            2.501449e-36
# 1     Value                  0.955618            1.586710e-36
# 2    Weight                  0.955482            1.433164e-36
#
#    Kolmogorov-Smirnov (Statistic)  Kolmogorov-Smirnov (P-Value)  \
# 0                        0.060265                  3.127844e-16
# 1                        0.059690                  6.243853e-16
# 2                        0.056943                  1.548810e-14
#
#    Anderson-Darling (Statistic)   Anderson-Darling (Critical-Values)  \
# 0                     53.503029  [0.576, 0.655, 0.786, 0.917, 1.091]
# 1                     52.984072  [0.576, 0.655, 0.786, 0.917, 1.091]
# 2                     53.345307  [0.576, 0.655, 0.786, 0.917, 1.091]
#
#   Anderson-Darling (Significance Levels)  Jarque-Bera (Statistic)  \
# 0            [15.0, 10.0, 5.0, 2.5, 1.0]               294.130368
# ...

# %% [markdown]
# ##### Test of Correlation {t}

# %%
# Select numerical variables for the test
sg47_numerical_data = sg47_sample_data[['Quantity', 'Value', 'Weight']]
# Define a function to calculate the t-test for correlation
def correlation_t_test(data):
    results = []

    # Loop through pairs of numerical variables
    for i, col1 in enumerate(data.columns):
        for j, col2 in enumerate(data.columns):
            if i < j:        # Avoid duplicate pairs
                # Pearson Correlation Coefficient
                sg47_r = data[col1].corr(data[col2])

                # Degrees of Freedom
                sg47_n = len(data[col1])
                sg47_df = sg47_n - 2

                # Calculate t-statistic
                sg47_t_stat = sg47_r * np.sqrt(sg47_df / (1 - sg47_r**2))

                # Calculate p-value
                sg47_p_value = 2 * (1 - t.cdf(abs(sg47_t_stat), sg47_df))

                # Store results
                results.append({
                    'Variable 1': col1,
                    'Variable 2': col2,
                    'Correlation Coefficient (r)': sg47_r,
                    't-Statistic': sg47_t_stat,
                    'p-Value': sg47_p_value})

    return pd.DataFrame(results)

# Perform the t-test for correlation
sg47_correlation_results = correlation_t_test(sg47_numerical_data)

# Display the results
print(sg47_correlation_results)
# Out:
#   Variable 1 Variable 2  Correlation Coefficient (r)  t-Statistic   p-Value
# 0   Quantity      Value                    -0.007698    -0.544306  0.586255
# 1   Quantity     Weight                     0.017973     1.270981  0.203795
# 2      Value     Weight                     0.008844     0.625325  0.531786

# %% [markdown]
# ### __Machine Learning Models__

# %% [markdown]
# #### _Supervised Machine Learning_
# #### Classification & Regression

# %% [markdown]
# ##### **Logistic Regression** (Classification Report | Confusion Matrix)

# %%
# Define feature and target columns
sg47_feature = ['Category_code','Shipping_Method_code','Payment_Terms_code','Quantity_mmnorm','Value_mmnorm','Weight_mmnorm']
sg47_target = 'Import_Export_code'

# Split the data into features and target
sg47_x = sg47_ppd[sg47_feature]  # Features
sg47_y = sg47_ppd[sg47_target]    # Target

# Split the dataset into training and testing sets
sg47_x_train, sg47_x_test, sg47_y_train, sg47_y_test = train_test_split(sg47_x, sg47_y, test_size=0.3, random_state=55047)

# Train Logistic Regression
sg47_model = LogisticRegression()
sg47_model.fit(sg47_x_train, sg47_y_train)

# Make predictions
sg47_y_pred = sg47_model.predict(sg47_x_test)

# Evaluate the model
print("Accuracy:", accuracy_score(sg47_y_test, sg47_y_pred))
print("\nClassification Report:\n", classification_report(sg47_y_test, sg47_y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(sg47_y_test, sg47_y_pred))
# Out:
# Accuracy: 0.5289806795469687
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.52      0.40      0.45       724
#          1.0       0.54      0.65      0.59       777
#
#     accuracy                           0.53      1501
#    macro avg       0.53      0.52      0.52      1501
# weighted avg       0.53      0.53      0.52      1501
#
#
# Confusion Matrix:
#  [[291 433]
#  [274 503]]

# %% [markdown]
# ##### **Support Vector Machines** (Classification Report | Confusion Matrix)

# %%
# Define feature and target columns
sg47_feature_columns = ['Category_code','Shipping_Method_code','Payment_Terms_code','Quantity_mmnorm','Value_mmnorm','Weight_mmnorm']
sg47_target_column = 'Import_Export_code'

# Split the data into features and target
sg47_D = sg47_ppd[sg47_feature_columns]  # Features
sg47_T = sg47_ppd[sg47_target_column]    # Target

# Split the dataset into training and testing sets
sg47_D_train, sg47_D_test, sg47_T_train, sg47_T_test = train_test_split(sg47_D, sg47_T, test_size=0.3, random_state=55047)

# Initialize and train the Support Vector Machine model
sg47_svm_model = SVC(kernel='rbf', C=1.0, gamma='scale')  # RBF kernel, regularization parameter C=1.0
sg47_svm_model.fit(sg47_D_train, sg47_T_train)

# Predict on the test set
sg47_T_pred = sg47_svm_model.predict(sg47_D_test)

# Evaluate the model
print("Confusion Matrix:")
print(confusion_matrix(sg47_T_test, sg47_T_pred))
print("\nClassification Report:")
print(classification_report(sg47_T_test, sg47_T_pred))

# Visualizing the Confusion Matrix
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(sg47_T_test, sg47_T_pred), annot=True, fmt='d', cmap='Blues', xticklabels=sg47_T.unique(), yticklabels=sg47_T.unique())
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Confusion Matrix:
# [[326 398]
#  [380 397]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.45      0.46       724
#          1.0       0.50      0.51      0.51       777
#
#     accuracy                           0.48      1501
#    macro avg       0.48      0.48      0.48      1501
# weighted avg       0.48      0.48      0.48      1501

# %% [markdown]
# ##### **Stochastic Gradient Descent** (Classification Report | Confusion Matrix)

# %%
sg47_D2 = sg47_ppd[['Category_code', 'Shipping_Method_code', 'Payment_Terms_code', 'Quantity_mmnorm', 'Value_mmnorm', 'Weight_mmnorm']]  # Features
sg47_T2 = sg47_ppd['Import_Export_code']  #Target

# Split the dataset into training and testing sets
sg47_D2_train, sg47_D2_test, sg47_T2_train, sg47_T2_test = train_test_split(sg47_D2, sg47_T2, test_size=0.3, random_state=55047)

# Initialize the SGDClassifier
sg47_sgd_classifier = SGDClassifier(max_iter=1000, tol=1e-3, random_state=55047)

# Train the model
sg47_sgd_classifier.fit(sg47_D2_train, sg47_T2_train)

# Predict on the test set
sg47_T2_pred = sg47_sgd_classifier.predict(sg47_D2_test)

# Evaluate the model
print("Accuracy:", accuracy_score(sg47_T2_test, sg47_T2_pred))
print("\nConfusion Matrix:")
print(confusion_matrix(sg47_T2_test, sg47_T2_pred))
print("\nClassification Report:")
print(classification_report(sg47_T2_test, sg47_T2_pred))

# Visualizing the Confusion Matrix
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(sg47_T2_test, sg47_T2_pred), annot=True, fmt='d', cmap='winter')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Accuracy: 0.4823451032644903
#
# Confusion Matrix:
# [[724   0]
#  [777   0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.48      1.00      0.65       724
#          1.0       0.00      0.00      0.00       777
#
#     accuracy                           0.48      1501
#    macro avg       0.24      0.50      0.33      1501
# weighted avg       0.23      0.48      0.31      1501
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# ##### **Decision Trees** (Classification Report | Confusion Matrix)

# %%
sg47_z2 = sg47_ppd[['Category_code', 'Shipping_Method_code', 'Payment_Terms_code', 'Quantity_mmnorm', 'Value_mmnorm', 'Weight_mmnorm']]  # Features
sg47_z = sg47_ppd['Import_Export_code']  #Target

# Split the dataset into training and testing sets
sg47_z2_train, sg47_z2_test, sg47_z_train, sg47_z_test = train_test_split(sg47_z2, sg47_z, test_size=0.3, random_state=55047)

# Train a Decision Tree Classifier
sg47_clf = DecisionTreeClassifier(random_state=55047)
sg47_clf.fit(sg47_z2_train, sg47_z_train)

# Make predictions
sg47_z_pred = sg47_clf.predict(sg47_z2_test)

# Evaluate the model
print("Accuracy:", accuracy_score(sg47_z_test, sg47_z_pred))
print("\nClassification Report:\n", classification_report(sg47_z_test, sg47_z_pred))
print("\nConfusion Matrix:\n", confusion_matrix(sg47_z_test, sg47_z_pred))

# Visualize the Decision Tree
plt.figure(figsize=(10, 5))

# Ensure feature names are valid column names from the training data
plot_tree(
    sg47_clf,
    feature_names=list(sg47_z2.columns),  # Convert columns to a list
    class_names=[str(cls) for cls in sg47_clf.classes_],  # Ensure classes are strings
    filled=True)

plt.title("Decision Tree Visualization")
plt.show()
# Out:
# Accuracy: 0.502998001332445
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.49      0.52      0.50       724
#          1.0       0.52      0.49      0.51       777
#
#     accuracy                           0.50      1501
#    macro avg       0.50      0.50      0.50      1501
# weighted avg       0.50      0.50      0.50      1501
#
#
# Confusion Matrix:
#  [[373 351]
#  [395 382]]

# %% [markdown]
# ##### **K-Nearest Neighbors** (Classification Report | Confusion Matrix)

# %%
# Preparing features and target variables
sg47_D3 = sg47_ppd[['Category_code', 'Shipping_Method_code', 'Payment_Terms_code', 'Quantity_mmnorm', 'Value_mmnorm', 'Weight_mmnorm']]  # Features
sg47_T3 = sg47_ppd['Import_Export_code']  # Target

# Split the dataset into training and testing sets
sg47_D3_train, sg47_D3_test, sg47_T3_train, sg47_T3_test = train_test_split(sg47_D3, sg47_T3, test_size=0.3, random_state=55047)

# Initialize the KNN classifier
sg47_knn_classifier = KNeighborsClassifier(n_neighbors=5)      # 5 is a commonly used value

# Train the model
sg47_knn_classifier.fit(sg47_D3_train, sg47_T3_train)

# Predict on the test set
sg47_T3_pred = sg47_knn_classifier.predict(sg47_D3_test)

# Evaluate the model
print("Accuracy:", accuracy_score(sg47_T3_test, sg47_T3_pred))
print("\nConfusion Matrix:")
print(confusion_matrix(sg47_T3_test, sg47_T3_pred))
print("\nClassification Report:")
print(classification_report(sg47_T3_test, sg47_T3_pred))

# Visualizing the Confusion Matrix
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(sg47_T3_test, sg47_T3_pred), annot=True, fmt='d', cmap='viridis')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Accuracy: 0.49300466355762823
#
# Confusion Matrix:
# [[359 365]
#  [396 381]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.50      0.49       724
#          1.0       0.51      0.49      0.50       777
#
#     accuracy                           0.49      1501
#    macro avg       0.49      0.49      0.49      1501
# weighted avg       0.49      0.49      0.49      1501

# %% [markdown]
# ##### **Naive Bayes** (Classification Report | Confusion Matrix)

# %%
# Define features (D) and target (T)
sg47_D4 = sg47_ppd.drop(columns=['Import_Export_code'])
sg47_T4 = sg47_ppd['Import_Export_code']

# Split the data into training and test sets
sg47_D4_train, sg47_D4_test, sg47_T4_train, sg47_T4_test = train_test_split(sg47_D4, sg47_T4, test_size=0.3, random_state=55047)

# Initialize the Naive Bayes model
sg47_nb_model = GaussianNB()

# Train the model
sg47_nb_model.fit(sg47_D4_train, sg47_T4_train)

# Predict on the test set
sg47_T4_pred = sg47_nb_model.predict(sg47_D4_test)

# Evaluate the model
print("Confusion Matrix:")
print(confusion_matrix(sg47_T4_test, sg47_T4_pred))

print("\nClassification Report:")
print(classification_report(sg47_T4_test, sg47_T4_pred))

# Visualizing the Confusion Matrix
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(sg47_T4_test, sg47_T4_pred), annot=True, fmt='d', cmap='autumn')
plt.title("Confusion Matrix for Naive Bayes")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Confusion Matrix:
# [[298 426]
#  [283 494]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.51      0.41      0.46       724
#          1.0       0.54      0.64      0.58       777
#
#     accuracy                           0.53      1501
#    macro avg       0.52      0.52      0.52      1501
# weighted avg       0.53      0.53      0.52      1501

# %% [markdown]
# ##### __Ensembles (Bagging | Boosting)__:
# **- Random Forest**

# %%
sg47_a = sg47_ppd[['Category_code', 'Shipping_Method_code', 'Payment_Terms_code', 'Quantity_mmnorm', 'Value_mmnorm', 'Weight_mmnorm']]  # Features
sg47_b = sg47_ppd['Import_Export_code']  # Target

# Split the dataset into training and testing sets
sg47_a_train, sg47_a_test, sg47_b_train, sg47_b_test = train_test_split(sg47_a, sg47_b, test_size=0.3, random_state=55047)

# Train a Random Forest Classifier
sg47_rf_clf = RandomForestClassifier(n_estimators=100, random_state=55047)
sg47_rf_clf.fit(sg47_a_train, sg47_b_train)

# Make predictions
sg47_b_pred = sg47_rf_clf.predict(sg47_a_test)
sg47_b_pred_proba = sg47_rf_clf.predict_proba(sg47_a_test)[:, 1]              # For AUC-ROC if needed

# Evaluate the model
print("Accuracy:", accuracy_score(sg47_b_test, sg47_b_pred))
print("\nClassification Report:\n", classification_report(sg47_b_test, sg47_b_pred))
print("\nConfusion Matrix:\n", confusion_matrix(sg47_b_test, sg47_b_pred))

# Plot Feature Importances
feature_importances = pd.DataFrame({
    'Feature': sg47_a.columns,
    'Importance': sg47_rf_clf.feature_importances_}).sort_values(by='Importance', ascending=False)

plt.figure(figsize=(12, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importances)
plt.title('Feature Importances')
plt.show()
# Out:
# Accuracy: 0.5109926715522984
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.49      0.54      0.51       724
#          1.0       0.53      0.49      0.51       777
#
#     accuracy                           0.51      1501
#    macro avg       0.51      0.51      0.51      1501
# weighted avg       0.51      0.51      0.51      1501
#
#
# Confusion Matrix:
#  [[388 336]
#  [398 379]]

# %% [markdown]
# **- Extreme Gradient Boosting**

# %%
pip install xgboost

# %%
# Define features (D) and target (T)
sg47_D5 = sg47_ppd.drop(columns=['Import_Export_code'])
sg47_T5 = sg47_ppd['Import_Export_code']

# Split the data into training and test sets
sg47_D5_train, sg47_D5_test, sg47_T5_train, sg47_T5_test = train_test_split(sg47_D5, sg47_T5, test_size=0.3, random_state=55047)

# Initialize the XGBoost model
sg47_xgb_model = xgb.XGBClassifier(objective='binary:logistic', eval_metric='logloss', use_label_encoder=False)

# Train the model
sg47_xgb_model.fit(sg47_D5_train, sg47_T5_train)

# Predict on the test set
sg47_T5_pred = sg47_xgb_model.predict(sg47_D5_test)

# Evaluate the model
sg47_accuracy = accuracy_score(sg47_T5_test, sg47_T5_pred)
print(f"Accuracy: {sg47_accuracy * 100:.2f}%")

# Confusion Matrix
print("\nConfusion Matrix:")
print(confusion_matrix(sg47_T5_test, sg47_T5_pred))

print("\nClassification Report:")
print(classification_report(sg47_T5_test, sg47_T5_pred))

# Visualizing the Confusion Matrix
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(sg47_T5_test, sg47_T5_pred), annot=True, fmt='d', cmap='plasma')
plt.title("Confusion Matrix for XGBoost")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [06:04:58] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Accuracy: 49.63%
#
# Confusion Matrix:
# [[349 375]
#  [381 396]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.48      0.48       724
#          1.0       0.51      0.51      0.51       777
#
#     accuracy                           0.50      1501
#    macro avg       0.50      0.50      0.50      1501
# weighted avg       0.50      0.50      0.50      1501

# %% [markdown]
# _**Cross-Validation (K-Fold)**_

# %%
# Perform K-Fold Cross-Validation
sg47_k = 5                                  # Number of folds
sg47_kf = KFold(n_splits=sg47_k, shuffle=True, random_state=55047)

# Collect metrics
sg47_fold_accuracies = []
sg47_b_pred_all = []

for train_index, test_index in sg47_kf.split(sg47_a):
    # Split the data
    sg47_a_train, sg47_a_test = sg47_a.iloc[train_index], sg47_a.iloc[test_index]
    sg47_b_train, sg47_b_test = sg47_b.iloc[train_index], sg47_b.iloc[test_index]

    # Train the model
    sg47_rf_clf.fit(sg47_a_train, sg47_b_train)

    # Make predictions
    sg47_b_pred = sg47_rf_clf.predict(sg47_a_test)
    sg47_b_pred_all.extend(sg47_b_pred)

    # Evaluate accuracy for the current fold
    sg47_accuracy = accuracy_score(sg47_b_test, sg47_b_pred)
    sg47_fold_accuracies.append(sg47_accuracy)

# Average accuracy across all folds
sg47_average_accuracy = np.mean(sg47_fold_accuracies)
print(f"K-Fold Cross-Validation Results ({sg47_k} Folds):")
print(f"Fold Accuracies: {sg47_fold_accuracies}")
print(f"Average Accuracy: {sg47_average_accuracy:.4f}")
# Out:
# K-Fold Cross-Validation Results (5 Folds):
# Fold Accuracies: [0.4995004995004995, 0.507, 0.48, 0.537, 0.507]
# Average Accuracy: 0.5061

# %% [markdown]
# #### Model Run Statistics
# ##### Time Taken

# %%
sg47_time_data = load_iris()
sg47_X = sg47_time_data.data
sg47_y = sg47_time_data.target

# Split the dataset
sg47_X_train, sg47_X_test, sg47_y_train, sg47_y_test = train_test_split(sg47_X, sg47_y, test_size=0.3, random_state=55047)

# Models to test
sg47_models = {
    "Logistic Regression (LR)": LogisticRegression(),
    "Support Vector Machine (SVM)": SVC(),
    "Stochastic Gradient Descent (SGD)": SGDClassifier(),
    "Decision Tree (DT)": DecisionTreeClassifier(),
    "K-Nearest Neighbors (KNN)": KNeighborsClassifier(),
    "Naive Bayes (NB)": GaussianNB(),
    "Random Forest (RF)": RandomForestClassifier(),
    "XGBoost": xgb.XGBClassifier()
}

# Measure the time taken for each model
for model_name, model in sg47_models.items():
    start_time = time.time()
    sg47_model.fit(sg47_X_train, sg47_y_train)
    end_time = time.time()
    training_time = end_time - start_time
    print(f"Time taken by {model_name}: {training_time:.4f} seconds")
# Out:
# Time taken by Logistic Regression (LR): 0.0168 seconds
# Time taken by Support Vector Machine (SVM): 0.0233 seconds
# Time taken by Stochastic Gradient Descent (SGD): 0.0177 seconds
# Time taken by Decision Tree (DT): 0.0171 seconds
# Time taken by K-Nearest Neighbors (KNN): 0.0164 seconds
# Time taken by Naive Bayes (NB): 0.0175 seconds
# Time taken by Random Forest (RF): 0.0164 seconds
# Time taken by XGBoost: 0.0176 seconds

# %% [markdown]
# ##### Memory Used

# %%
pip install memory-profiler xgboost

# %%
from memory_profiler import memory_usage                                                # For memory used
sg47_X = sg47_ppd  # Features
sg47_y = sg47_ppd['Import_Export_code']  # Target

# Split your dataset into training and testing sets
sg47_X_train, sg47_X_test, sg47_y_train, sg47_y_test = train_test_split(sg47_X, sg47_y, test_size=0.3, random_state=55047)

# Define models
sg47_models = {
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=55047),
    "Support Vector Machine": SVC(probability=True, random_state=55047),
    "Stochastic Gradient Descent": SGDClassifier(max_iter=1000, random_state=55047),
    "Decision Tree": DecisionTreeClassifier(random_state=55047),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Naive Bayes": GaussianNB(),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=55047),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=55047)
}

# Function to train and evaluate a model while measuring memory usage
def train_and_measure_memory(sg47_model, sg47_X_train, sg47_y_train, sg47_X_test, sg47_y_test):
    def wrapper():
        sg47_model.fit(sg47_X_train, sg47_y_train)  # Train the model
        sg47_model.predict(sg47_X_test)       # Predict on the test set

    # Measure memory usage during the wrapper execution
    sg47_mem_usage = memory_usage(wrapper, interval=0.1)
    return max(sg47_mem_usage) - min(sg47_mem_usage)

# Measure memory usage for each model
sg47_memory_results = {}
for model_name, model in sg47_models.items():
    print(f"Training {model_name}...")
    sg47_memory_used = train_and_measure_memory(model, sg47_X_train, sg47_y_train, sg47_X_test, sg47_y_test)
    sg47_memory_results[model_name] = sg47_memory_used
    print(f"{model_name} used {sg47_memory_used:.2f} MiB of memory.\n")

# Display results
print("Memory Usage (in MiB) by Each Model:")
for model_name, mem in sg47_memory_results.items():
    print(f"{model_name}: {mem:.2f} MiB")
# Out:
# Training Logistic Regression...
# Logistic Regression used 0.12 MiB of memory.
#
# Training Support Vector Machine...
# Support Vector Machine used 0.03 MiB of memory.
#
# Training Stochastic Gradient Descent...
# Stochastic Gradient Descent used 0.00 MiB of memory.
#
# Training Decision Tree...
# Decision Tree used 0.00 MiB of memory.
#
# Training K-Nearest Neighbors...
# K-Nearest Neighbors used 0.00 MiB of memory.
#
# Training Naive Bayes...
# Naive Bayes used 0.00 MiB of memory.
#
# Training Random Forest...
# Random Forest used 0.00 MiB of memory.
#
# Training XGBoost...
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [06:30:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost used 0.05 MiB of memory.
#
# Memory Usage (in MiB) by Each Model:
# Logistic Regression: 0.12 MiB
# Support Vector Machine: 0.03 MiB
# Stochastic Gradient Descent: 0.00 MiB
# ...

# %% [markdown]
# ##### Inherent Complexity

# %%
X = sg47_ppd  # Features
y = sg47_ppd['Import_Export_code']  # Target variable

# Split your dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=55047)

# Define models
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=55047),
    "Support Vector Machine": SVC(probability=True, random_state=55047),
    "Stochastic Gradient Descent": SGDClassifier(max_iter=1000, random_state=55047),
    "Decision Tree": DecisionTreeClassifier(random_state=55047),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Naive Bayes": GaussianNB(),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=55047),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=55047)
}

# Function to compute model complexity metrics
def measure_model_complexity(model, X_train, y_train):
    start_time = time.time()  # Start time
    model.fit(X_train, y_train)  # Train the model
    end_time = time.time()  # End time
    training_time = end_time - start_time  # Training time

    # Check the number of parameters if the model supports it
    if hasattr(model, "coef_"):  # For linear models
        num_params = model.coef_.size
    elif hasattr(model, "n_features_in_"):  # For decision trees, RF
        num_params = model.n_features_in_
    else:
        num_params = "Not Applicable"  # For models where it's hard to define

    return {
        "Training Time (s)": training_time,
        "Number of Parameters": num_params if num_params != "Not Applicable" else 0
    }

# Measure complexity for each model
complexity_results = []
for model_name, model in models.items():
    print(f"Measuring complexity for {model_name}...")
    complexity = measure_model_complexity(model, X_train, y_train)
    complexity_results.append({
        "Model": model_name,
        "Training Time (s)": complexity["Training Time (s)"],
        "Number of Parameters": complexity["Number of Parameters"]
    })

# Convert results to a DataFrame
complexity_df = pd.DataFrame(complexity_results)

# Visualization: Training Time
plt.figure(figsize=(12, 6))
sns.barplot(data=complexity_df, x="Model", y="Training Time (s)", palette="viridis")
plt.title("Training Time by Model")
plt.ylabel("Training Time (seconds)")
plt.xlabel("Model")
plt.xticks(rotation=45)
plt.show()

# Visualization: Number of Parameters
plt.figure(figsize=(12, 6))
sns.barplot(data=complexity_df, x="Model", y="Number of Parameters", palette="magma")
plt.title("Number of Parameters by Model")
plt.ylabel("Number of Parameters")
plt.xlabel("Model")
plt.xticks(rotation=45)
plt.show()
# Out:
# Measuring complexity for Logistic Regression...
# Measuring complexity for Support Vector Machine...
# Measuring complexity for Stochastic Gradient Descent...
# Measuring complexity for Decision Tree...
# Measuring complexity for K-Nearest Neighbors...
# Measuring complexity for Naive Bayes...
# Measuring complexity for Random Forest...
# Measuring complexity for XGBoost...
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [06:30:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# <ipython-input-86-bbaa1a363696>:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=complexity_df, x="Model", y="Training Time (s)", palette="viridis")
# <ipython-input-86-bbaa1a363696>:64: FutureWarning:
#
# ...

# %% [markdown]
# -x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-x-
